# %% [markdown]
# ## Mapping Colonial Medical Expertise of the Old Regime ##
# ### Sean Takats, George Mason University ###
#
# In *la zone torride*, where French colonial efforts were effectively confined after the Seven Years War, profitable commerce and brutal mortality rates combined to produce a steady supply of desperate but paying patients. Just as the colonies of the Old Regime provided the chance for planters and traders to grow rich (faire fortune), they also promised to reward doctors who could keep those individuals healthy in the face of endemic disease. Chasing fame and wealth, hundreds of medical practitioners fanned out across the globe from France to support a growing colonial and military infrastructure. At the same time, they built up a new body of medical knowledge that might prove useful in the metropole, where neo-Hippocratic conceptions of disease and hygiene were pushed to their limits by colonial findings.
#
# Despite perceived importance of this endeavor, with a range of new royal institutions established to support it, few historical studies have treated colonial medical practitioners apart from their published medical treatises, and medical histories of the Old Regime largely neglect colonial medicine. This neglect reflects at least in part a methodological bias, which this paper addresses. While many of doctors recounted their colonial experiences in published articles and books, the vast majority did not, and records of their experiences remain largely ignored in the archives. Only by considering it in its totality can we regain a sense of the centrality of this exotic experience to contemporary medical practice.
#
# This paper seeks to visualize what that expertise might have looked like over the course of the eighteenth century. By computationally processing digital records of the Archives nationales d’Outre-Mer, I generate preliminary maps that suggest the development of increasingly dense and complex patterns of tropical medical expertise after 1750. I draw on approximately 20,000 records of French colonial agents and hundreds of medical practitioners included among them to explore the shifting centers of gravity of the colonial medical enterprise over the course of the eighteenth century. By seeking a concordance of medical expertise with the location in time and space of the experts themselves, we will have a clearer sense of how colonial medicine happened on the ground.

# %% [markdown]
# ## Data Processing ##
# I downloaded and processed all 19,338 entries in the finding aid for [Série E of the Archives nationales d’Outre-Mer](http://anom.archivesnationales.culture.gouv.fr/ark:/61561/up424ojc). This finding aid indexes 63 linear meters of records, stored in 441 cartons. Each record in the finding aid looks something like this:
#
# *Artur, Jacques François, médecin et doyen du Conseil supérieur à Cayenne 1735/1781*
#
# We can immediately see that there’s a significant amount of information in this record that could be useful to us: name, occupation, location, and time. Each record in the finding aid contains at least a name, and most contain a full complement of data, often with multiple locations (more on this later).
#
# A finding aid like this one, however, is typically used to conduct a search. And search as a research strategy is, of course, problematic. The finding aid itself is not granted any particular significance or use in its own right. For example, if I wanted to find out something about doctors, I might search for “médecin” and find some records, including Artur’s. Or I might be interested in Guyane and search “Cayenne”, again finding his record. But both of those searches presuppose a great deal. I’ve already decided to look for “Cayenne” but how do I even know if Guyana is important at all? Things get even more complicated if I want to think about time. How can I find records of individuals that intersect with a certain period? To make such queries possible, we can instead consider the finding aid in the aggregate, to identify times and places that may encourage further investigation. In other words, why not attempt a distant reading of the records, via computational analysis of their metadata?
#
# Once I had loaded all the records into a database, I then extracted the metadata from each record: personal name, place name(s), and military corps name (persname, geogname, and corpname, in ANOM’s schema), along with any years provided. With the Series E records now searchable, sortable, and (most important) containing structured data, I could then begin to view the dataset in the aggregate. At this stage, however, we are still working with fundamentally qualitative data (other than the years).

# %%
import re, sys
import pandas as pd, numpy as np
import pickle
from bs4 import BeautifulSoup

# %%
# I'm currently storing my downloaded data from ANOM using jupyter persistence
# we'll load personneldf from here
# %store -r

# %% [markdown]
# ## Filter "medical" personnel ##
# My next step was to pass the database of colonial agents through a filter to identify medical personnel, flagging any record that included “santé”, “médic”, “médecin”, or “chirurg”, a process which yields 526 records. With these records in hand and a geocoded database of locations, we can now plot these colonial personnel in time and space.

# %%
medicaldf = personneldf[personneldf.fullRecord.str.contains('santé|médic|médecin|chirurg')]

# %%
medicaldf
# Out:
#                                                  archref  \
# 85     <a class="archref" href="/ark:/61561/up424g0z0...
# 89     <a class="archref" href="/ark:/61561/up424rlkp...
# 102    <a class="archref" href="/ark:/61561/up424xrry...
# 118    <a class="archref" href="/ark:/61561/up424uoqr...
# 190    <a class="archref" href="/ark:/61561/up424rmkq...
# 245    <a class="archref" href="/ark:/61561/up424pkoj...
# 264    <a class="archref" href="/ark:/61561/up424niog...
# 267    <a class="archref" href="/ark:/61561/up424toup...
# 301    <a class="archref" href="/ark:/61561/up424dzx3...
# 372    <a class="archref" href="/ark:/61561/up424rnss...
# 375    <a class="archref" href="/ark:/61561/up424dz5x...
# 397    <a class="archref" href="/ark:/61561/up424qnkm...
# 399    <a class="archref" href="/ark:/61561/up424qnko...
# 475    <a class="archref" href="/ark:/61561/up424xuzr...
# 528    <a class="archref" href="/ark:/61561/up424ywvv...
# 579    <a class="archref" href="/ark:/61561/up424wuyu...
# 584    <a class="archref" href="/ark:/61561/up424e3xx...
# 659    <a class="archref" href="/ark:/61561/up424zyzy...
# 675    <a class="archref" href="/ark:/61561/up424kjmf...
# 688    <a class="archref" href="/ark:/61561/up424ppin...
# 701    <a class="archref" href="/ark:/61561/up424ppjq...
# 784    <a class="archref" href="/ark:/61561/up424wxpq...
# 860    <a class="archref" href="/ark:/61561/up424a100...
# 862    <a class="archref" href="/ark:/61561/up424pqpr...
# 877    <a class="archref" href="/ark:/61561/up424jklg...
# 893    <a class="archref" href="/ark:/61561/up424oqih...
# 906    <a class="archref" href="/ark:/61561/up424y0tu...
# 931    <a class="archref" href="/ark:/61561/up424npko...
# 993    <a class="archref" href="/ark:/61561/up424dxwx...
# 1001   <a class="archref" href="/ark:/61561/up424fzyz...
# ...                                                  ...
# 17717  <a class="archref" href="/ark:/61561/up424wqww...
# 17852  <a class="archref" href="/ark:/61561/up424au01...
# 17860  <a class="archref" href="/ark:/61561/up424jdjk...
# 17892  <a class="archref" href="/ark:/61561/up424jdjl...
# 17896  <a class="archref" href="/ark:/61561/up424icik...
# 18013  <a class="archref" href="/ark:/61561/up424mgnf...
# 18052  <a class="archref" href="/ark:/61561/up424oiph...
# 18099  <a class="archref" href="/ark:/61561/up424smtm...
# 18120  <a class="archref" href="/ark:/61561/up424fz6z...
# 18165  <a class="archref" href="/ark:/61561/up424oipi...
# 18233  <a class="archref" href="/ark:/61561/up424dx4y...
# 18251  <a class="archref" href="/ark:/61561/up424cw3x...
# 18300  <a class="archref" href="/ark:/61561/up424au1w...
# 18328  <a class="archref" href="/ark:/61561/up424xryt...
# 18359  <a class="archref" href="/ark:/61561/up424vpwr...
# 18401  <a class="archref" href="/ark:/61561/up424ey51...
# 18404  <a class="archref" href="/ark:/61561/up424vpws...
# 18426  <a class="archref" href="/ark:/61561/up424yszv...
# 18521  <a class="archref" href="/ark:/61561/up424hbif...
# 18649  <a class="archref" href="/ark:/61561/up424smtr...
# 18776  <a class="archref" href="/ark:/61561/up424nhoo...
# 18854  <a class="archref" href="/ark:/61561/up424g077...
# 18863  <a class="archref" href="/ark:/61561/up424cw33...
# 19064  <a class="archref" href="/ark:/61561/up424ys0r...
# 19083  <a class="archref" href="/ark:/61561/up424dx5x...
# 19228  <a class="archref" href="/ark:/61561/up424wqyr...
# 19244  <a class="archref" href="/ark:/61561/up424ey6z...
# 19276  <a class="archref" href="/ark:/61561/up424oiqk...
# 19291  <a class="archref" href="/ark:/61561/up424oiqk...
# 19300  <a class="archref" href="/ark:/61561/up424pjrl...
#
#                                                    name  \
# 85                                        Akers, Arétas
# 89                                             Alavoine
# 102                                     Albert, Nicolas
# 118                                             Aleaume
# 190                          Amelin de Lacroix, Charles
# 245                                 Angerville, Côme d'
# 264                                   Annibal, François
# 267                                Ansermet, Jean Louis
# 301                                         Archambault
# 372                                       Arnoux, André
# 375                                      Arnoux, Joseph
# 397                                             Arthaud
# 399                             Artur, Jacques François
# 475              Aucam de Sainte-Anne, Nicolas François
# 528                                              Aumand
# 579                                    Avril, Michel d'
# 584                                              Aymard
# 659                                     Bajon, Bertrand
# 675                                 Balet, Frère Elzéar
# 688                                      Ballay, Claude
# 701                                               Bally
# 784                                  Barbudeau, Gabriel
# 860                            Barronnat, Jean Baptiste
# 862                                             Barrout
# 877                                              Barthe
# 893                                               Baslé
# 906                                      Bassot, Hugues
# 931                            Baudamant, Jean Baptiste
# 993                                             Bautier
# 1001                                              Bayet
# ...                                                 ...
# 17717                                    Silay, Gaspard
# 17852                                         Souberbie
# 17860                                   Souchon, Claude
# 17892                                Souverbie, Jacques
# 17896                                 Spadea, Dominique
# 18013                                             Tains
# 18052                         Tartonne, Joseph Palamède
# 18099                                   Ténèbre, Gilles
# 18120         Terrier de Laistre, Louis Augustin Blaise
# 18165                                    Thenet, Pierre
# 18233                  Thierry, Jean Baptiste Balthazar
# 18251                                           Thirion
# 18300  Thoreau de La Touchardière, André Joseph Laurent
# 18328                                             Thyon
# 18359                                  Tisseran, Pierre
# 18401                        Tosgobby, François Antoine
# 18404                                      Touchardière
# 18426                                 Tournier, Gaspard
# 18521                     Troisoeufs-Finisterre, Blaise
# 18649                                             Valin
# 18776                        Vaujours, Jean Baptiste de
# 18854                             Vergnes de Bonischère
# 18863                       Vermond de Fresne, Henri de
# 19064                     Villeneuve, Michel Antoine de
# 19083                Villers-Beaulieu, Gilles Julien de
# 19228                                            Wallet
# 19244                                  Warnet, François
# 19276                          Wetterwald, Joseph Léger
# 19291                                            Wilmet
# 19300                                   Worlock, Siméon
#
#                                         placesdisplay  \
# 85                                    [Saint-Vincent]
# 89                                   [Trois-Rivières]
# 102                                               NaN
# 118                                    [Sainte-Lucie]
# 190                                  [Saint-Domingue]
# 245                                    [Cap-Français]
# 264                             [Indes, Chandernagor]
# 267                                   [île de France]
# 301                                      [Madagascar]
# 372                                          [Québec]
# 375    [Saint-Pierre et Miquelon, Martinique, Tabago]
# 397                                  [Saint-Domingue]
# 399                                         [Cayenne]
# 475                                      [Guadeloupe]
# 528                                               NaN
# 579                                         [Sénégal]
# 584                                  [Saint-Domingue]
# 659                                [Cayenne, Cayenne]
# 675                                      [Guadeloupe]
# 688                                  [Saint-Domingue]
# 701                                  [Saint-Domingue]
# 784                                  [île Saint-Jean]
# 860                   [Boën-sur-Lignon, Cap-Français]
# 862                                            [Inde]
# 877                                   [île de France]
# 893                                  [îles Malouines]
# 906                       [Cluny, Bourgogne, Cayenne]
# 931                       [Verdun-sur-Meuse, Cayenne]
# 993                                      [Martinique]
# 1001                              [Cayes-Saint-Louis]
# ...                                               ...
# 17717                                    [Martinique]
# 17852                                  [Port-de-Paix]
# 17860                                [Port-au-Prince]
# 17892                                [Saint-Domingue]
# 17896                       [Calabre, Port-au-Prince]
# 18013                                    [Madagascar]
# 18052             [Salon en Provence, Saint-Domingue]
# 18099                                   [Mazulipatam]
# 18120             [Paris, Martinique, Saint-Domingue]
# 18165                                [Saint-Domingue]
# 18233                           [Martinique, Trinité]
# 18251                                    [Martinique]
# 18300                                 [Marie-Galante]
# 18328                                             NaN
# 18359                                  [Sainte-Lucie]
# 18401                         [Paris, Saint-Domingue]
# 18404                                 [Marie-Galante]
# 18426                                       [Cayenne]
# 18521                                  [Saint-Pierre]
# 18649                                        [Tabago]
# 18776                                       [Grenade]
# 18854                                    [Guadeloupe]
# 18863                                    [Martinique]
# 19064                                  [Fort-Dauphin]
# 19083                                             NaN
# 19228                                     [Dominique]
# 19244                                    [Pondichéry]
# 19276                                         [Gorée]
# 19291                                         [Indes]
# 19300                       [Antigue, Saint-Domingue]
#
#                                         placesnormalized  \
# 85                       [Saint-Vincent, Île (Antilles)]
# 89                             [Trois-Rivières (Canada)]
# 102                                                  NaN
# 118                       [Sainte-Lucie, Île (Antilles)]
# 190    [Saint-Domingue, Colonie française (Saint-Domi...
# 245              [Cap-Français (Saint-Domingue, Île de)]
# 264                [Inde française, Chandernagor (Inde)]
# 267                [France, Île de (Mascareignes, Îles)]
# 301                                 [Madagascar, Île de]
# 372                                    [Québec (Canada)]
# 375    [Saint-Pierre-et-Miquelon, Archipel de, Martin...
# 397    [Saint-Domingue, Colonie française (Saint-Domi...
# 399                         [Cayenne (Guyane française)]
# 475                   [Guadeloupe, Île de la (Antilles)]
# 528                                                  NaN
# 579                                            [Sénégal]
# 584    [Saint-Domingue, Colonie française (Saint-Domi...
# 659    [Cayenne (Guyane française), Cayenne (Guyane f...
# 675                   [Guadeloupe, Île de la (Antilles)]
# 688    [Saint-Domingue, Colonie française (Saint-Domi...
# 701    [Saint-Domingue, Colonie française (Saint-Domi...
# 784                           [Saint-Jean, Île (Canada)]
# 860    [Boën (Loire ; France), Cap-Français (Saint-Do...
# 862                                     [Inde française]
# 877                [France, Île de (Mascareignes, Îles)]
# 893                                    [Malouines, Îles]
# 906    [Cluny (Saône-et-Loire ; France), Bourgogne, R...
# 931    [Verdun (Meuse ; France), Cayenne (Guyane fran...
# 993                   [Martinique, Île de la (Antilles)]
# 1001    [Les Cayes-Saint-Louis (Saint-Domingue, Île de)]
# ...                                                  ...
# 17717                 [Martinique, Île de la (Antilles)]
# 17852            [Port-de-Paix (Saint-Domingue, Île de)]
# 17860          [Port-au-Prince (Saint-Domingue, Île de)]
# 17892  [Saint-Domingue, Colonie française (Saint-Domi...
# 17896  [Calabre, Région géographique (Italie), Port-a...
# 18013                               [Madagascar, Île de]
# 18052  [Salon-de-Provence (Bouches-du-Rhône ; France)...
# 18099                               [Mazulipatam (Inde)]
# 18120  [Paris (France), Martinique, Île de la (Antill...
# 18165  [Saint-Domingue, Colonie française (Saint-Domi...
# 18233  [Martinique, Île de la (Antilles), La Trinité ...
# 18251                 [Martinique, Île de la (Antilles)]
# 18300                    [Marie-Galante, Île (Antilles)]
# 18328                                                NaN
# 18359                     [Sainte-Lucie, Île (Antilles)]
# 18401  [Paris (France), Saint-Domingue, Colonie franç...
# 18404                    [Marie-Galante, Île (Antilles)]
# 18426                       [Cayenne (Guyane française)]
# 18521             [Saint-Pierre (Martinique, Île de la)]
# 18649                           [Tabago, Île (Antilles)]
# 18776                       [Grenade, Île de (Antilles)]
# 18854                 [Guadeloupe, Île de la (Antilles)]
# 18863                 [Martinique, Île de la (Antilles)]
# 19064            [Fort-Dauphin (Saint-Domingue, Île de)]
# 19083                                                NaN
# 19228                  [Dominique, Île de la (Antilles)]
# 19244                                [Pondichéry (Inde)]
# 19276                          [Gorée, Île de (Sénégal)]
# 19291                                   [Inde française]
# 19300  [Antigua, Île (Antilles), Saint-Domingue, Colo...
#
#                                             corp startdate enddate  daterange  \
# 85                                                    1783    1783  1783-1783
# 89     Hôpital général (Trois-Rivières ; Canada)      1757    1761  1757-1761
# 102                                                   1786    1786  1786-1786
# 118                                                   1763    1763  1763-1763
# 190                                                   1770    1770  1770-1770
# 245                                                   1778    1780  1778-1780
# 264                                         None      1777    1778  1777-1778
# 267                                                   1774    1789  1774-1789
# 301                                                   1789    1789  1789-1789
# 372                                                   1746    1746  1746-1746
# 375                                                   1763    1783  1763-1783
# 397                                                   1772    1772  1772-1772
# 399         Conseil supérieur (Cayenne ; Guyane)      1735    1781  1735-1781
# 475                                                   1779    1779  1779-1779
# 528                                                   1783    1783  1783-1783
# 579                                                   1779    1782  1779-1782
# 584                                                   1777    1777  1777-1777
# 659                                                   1770    1778  1770-1778
# 675                         Frères de la Charité      1782    1782  1782-1782
# 688                                                   1764    1777  1764-1777
# 701
# 784                                                   1754    1771  1754-1771
# 860                                                   1785    1787  1785-1787
# 862                                                   1788    1788  1788-1788
# 877                       Régiment Royal-Comtois      1772    1775  1772-1775
# 893                                                   1764    1764  1764-1764
# 906                                                   1783    1783  1783-1783
# 931                                                   1777    1788  1777-1788
# 993                                                   1723    1723  1723-1723
# 1001                                                  1767    1767  1767-1767
# ...                                          ...       ...     ...        ...
# 17717                                                 1764    1764  1764-1764
# 17852                                                 1773    1773  1773-1773
# 17860                                                 1769    1769  1769-1769
# 17892                                                 1744    1759  1744-1759
# 17896                                                 1785    1785  1785-1785
# 18013                                                 1776    1776  1776-1776
# 18052                                                 1772    1772  1772-1772
# 18099                                                 1772    1778  1772-1778
# 18120                                                 1774    1789  1774-1789
# 18165                                                 1774    1789  1774-1789
# 18233                                                 1787    1787  1787-1787
# 18251                                                 1789    1791  1789-1791
# 18300                                                 1776    1783  1776-1783
# 18328                                                 1774    1774  1774-1774
# 18359                                                 1770    1771  1770-1771
# 18401                                                 1768    1773  1768-1773
# 18404                                                 1783    1783  1783-1783
# 18426                                                 1764    1770  1764-1770
# 18521                                                 1742    1742  1742-1742
# 18649                                                 1782    1782  1782-1782
# 18776                                                 1746    1773  1746-1773
# 18854                                                 1786    1787  1786-1787
# 18863                                                 1772    1788  1772-1788
# 19064                                                 1768    1776  1768-1776
# 19083                                                 1777    1792  1777-1792
# 19228                                                 1779    1779  1779-1779
# 19244                                                 1786    1786  1786-1786
# 19276                  Hôpital (Gorée ; Sénégal)      1764    1764  1764-1764
# 19291                                                 1788    1788  1788-1788
# 19300                                                 1779    1780  1779-1780
#
#                alldates                  fullLink  \
# 85                 1783    /ark:/61561/up424g0z0c
# 89           1757, 1761    /ark:/61561/up424rlkps
# 102                1786    /ark:/61561/up424xrryu
# 118                1763    /ark:/61561/up424uoqrg
# 190                1770    /ark:/61561/up424rmkqu
# 245          1778, 1780    /ark:/61561/up424pkojn
# 264          1777, 1778    /ark:/61561/up424niogg
# 267          1774, 1789    /ark:/61561/up424touph
# 301                1789    /ark:/61561/up424dzx3w
# 372                1746    /ark:/61561/up424rnssf
# 375          1763, 1783    /ark:/61561/up424dz5xy
# 397                1772    /ark:/61561/up424qnkmq
# 399          1735, 1781    /ark:/61561/up424qnkos
# 475                1779    /ark:/61561/up424xuzry
# 528                1783    /ark:/61561/up424ywvvb
# 579    1779, 1782, 1782    /ark:/61561/up424wuyuz
# 584                1777    /ark:/61561/up424e3xxv
# 659          1770, 1778    /ark:/61561/up424zyzyl
# 675                1782    /ark:/61561/up424kjmfb
# 688          1764, 1777    /ark:/61561/up424ppinq
# 701                        /ark:/61561/up424ppjqu
# 784          1754, 1771    /ark:/61561/up424wxpqp
# 860          1785, 1787    /ark:/61561/up424a100b
# 862                1788    /ark:/61561/up424pqprc
# 877          1772, 1775    /ark:/61561/up424jklgb
# 893                1764    /ark:/61561/up424oqihk
# 906                1783    /ark:/61561/up424y0tuf
# 931          1777, 1788    /ark:/61561/up424npkor
# 993                1723   /ark:/61561/up424dxwxwz
# 1001               1767   /ark:/61561/up424fzyz6u
# ...                 ...                       ...
# 17717        1764, 1764  /ark:/61561/up424wqwwttt
# 17852        1773, 1773  /ark:/61561/up424au0102m
# 17860              1769  /ark:/61561/up424jdjkkjb
# 17892        1744, 1759  /ark:/61561/up424jdjldlx
# 17896              1785  /ark:/61561/up424icikdem
# 18013        1776, 1776  /ark:/61561/up424mgnfjfb
# 18052              1772  /ark:/61561/up424oiphoqz
# 18099        1772, 1778  /ark:/61561/up424smtmnrq
# 18120        1774, 1789  /ark:/61561/up424fz6z25c
# 18165        1774, 1789  /ark:/61561/up424oipiqjv
# 18233              1787  /ark:/61561/up424dx4y2wj
# 18251        1789, 1791  /ark:/61561/up424cw3x23p
# 18300        1776, 1783  /ark:/61561/up424au1wv0v
# 18328              1774  /ark:/61561/up424xrytvvy
# 18359        1770, 1771  /ark:/61561/up424vpwrwuq
# 18401        1768, 1773  /ark:/61561/up424ey51z5y
# 18404              1783  /ark:/61561/up424vpwsrph
# 18426        1764, 1770  /ark:/61561/up424yszvwud
# 18521              1742  /ark:/61561/up424hbifeik
# 18649              1782  /ark:/61561/up424smtrssb
# 18776        1746, 1773  /ark:/61561/up424nhoogkp
# 18854        1786, 1787  /ark:/61561/up424g07771u
# 18863  1772, 1788, 1788  /ark:/61561/up424cw334wq
# 19064        1768, 1776  /ark:/61561/up424ys0r0tj
# 19083        1777, 1792  /ark:/61561/up424dx5xxxc
# 19228              1779  /ark:/61561/up424wqyruvt
# 19244              1786  /ark:/61561/up424ey6z4zt
# 19276              1764  /ark:/61561/up424oiqkhlr
# 19291              1788  /ark:/61561/up424oiqkiqx
# 19300        1779, 1780  /ark:/61561/up424pjrlkqd
#
#                                               fullRecord
# 85     Akers, Arétas, habitant de l'île Saint-Vincent...
# 89     Alavoine, chirurgien-major à l'hôpital des Tro...
# 102    Albert, Nicolas, botaniste ayant le privilège ...
# 118     Aleaume, docteur en médecine à Sainte-Lucie 1763
# 190    Amelin de Lacroix, Charles, chirurgien, passé ...
# 245    Angerville, Côme d', chirurgien du Roi, au Cap...
# 264    Annibal, François, novice du vaisseau le Borde...
# 267    Ansermet, Jean Louis, chirurgien à l'île de Fr...
# 301    Archambault, proposé pour chirurgien-major à M...
# 372    Arnoux, André, chirurgien-major du Roi à Québe...
# 375    Arnoux, Joseph, chirurgien du roi à Saint-Pier...
# 397    Arthaud, chirurgien embarqué pour Saint-Doming...
# 399    Artur, Jacques François, médecin et doyen du C...
# 475    Aucam de Sainte-Anne, Nicolas François, chirur...
# 528                              Aumand, chirurgien 1783
# 579    Avril, Michel d', chirurgien-major au Sénégal,...
# 584             Aymard, chirurgien à Saint-Domingue 1777
# 659    Bajon, Bertrand, chirurgien à Cayenne, et Raym...
# 675    Balet, Frère Elzéar, religieux de la Charité e...
# 688    Ballay, Claude, chirurgien-major à Saint-Domin...
# 701             Bally, médecin à Saint-Domingue [XVIIIe]
# 784    Barbudeau, Gabriel, chirurgien des troupes dét...
# 860    Barronnat, Jean Baptiste, de Boën-sur-Lignon (...
# 862    Barrout, chirurgien passant dans les états de ...
# 877    Barthe, chirurgien-major au régiment Royal-Com...
# 893    Baslé, chirurgien-major aux îles Malouines, et...
# 906    Bassot, Hugues, natif de Cluny en Bourgogne, c...
# 931    Baudamant, Jean Baptiste, né à Verdun-sur-Meus...
# 993      Bautier, chirurgien-major de la Martinique 1723
# 1001   Bayet, médecin du Roi, aux Cayes-Saint-Louis, ...
# ...                                                  ...
# 17717  Silay, Gaspard, maître-chirurgien à la Martini...
# 17852  Souberbie, chirurgien-major au Port-de-Paix à ...
# 17860  Souchon, Claude, médecin du Roi à Port-au-Prin...
# 17892  Souverbie, Jacques, chirurgien à Saint-Domingu...
# 17896  Spadea, Dominique, originaire de Calabre, méde...
# 18013  Tains, chirurgien à Madagascar, mort en 1776 1776
# 18052  Tartonne, Joseph Palamède, docteur en médecine...
# 18099  Ténèbre, Gilles, chirurgien du Roi, décédé à M...
# 18120  Terrier de Laistre, Louis Augustin Blaise, con...
# 18165  Thenet, Pierre, chirurgien-major à Saint-Domin...
# 18233  Thierry, Jean Baptiste Balthazar, habitant de ...
# 18251      Thirion, chirurgien à la Martinique 1789/1791
# 18300  Thoreau de La Touchardière, André Joseph Laure...
# 18328  Thyon, chirurgien inspecteur des recrues desti...
# 18359  Tisseran, Pierre, chirurgien-major du Roi à Sa...
# 18401  Tosgobby, François Antoine, docteur en médecin...
# 18404         Touchardière, médecin à Marie-Galante 1783
# 18426  Tournier, Gaspard, chirurgien du Roi à Cayenne...
# 18521  Troisoeufs-Finisterre, Blaise, chirurgien au F...
# 18649              Valin, chirurgien-major à Tabago 1782
# 18776  Vaujours, Jean Baptiste de, médecin du Roi à l...
# 18854  Vergnes de Bonischère, médecin du Roi à la Gua...
# 18863  Vermond de Fresne, Henri de, chirurgien à la M...
# 19064  Villeneuve, Michel Antoine de, en procès avec ...
# 19083  Villers-Beaulieu, Gilles Julien de, chirurgien...
# 19228       Wallet, chirurgien-major à la Dominique 1779
# 19244  Warnet, François, chirurgien-major à Pondichér...
# 19276  Wetterwald, Joseph Léger, chirurgien de l'hôpi...
# 19291              Wilmet, médecin envoyé aux Indes 1788
# 19300  Worlock, Siméon, né à Antigue, fixé à Saint-Do...
#
# [525 rows x 11 columns]

# %% [markdown]
# ## Geocode Place Names ##
#
# My next step was to geocode the place names embedded in each record. I extracted all the place names from my database of colonial personnel, rendering a list of 1401 unique location names. Fortunately ANOM offers a geographic lookup service, [Assistant de recherche géographique](http://anom.archivesnationales.culture.gouv.fr/geo.php), which provides GPS coordinates for the vast majority of these locations. I wrote a small piece of code to look up each location in the Assistant de recherche and then add the returned coordinates to my list of unique locations. I entered the small number of unreturned locations by hand using Wikipedia's geocodes.
#
# For the purposes of this analysis, we'll only use those locations which are associated with at least one medical practitioner, i.e. ones that match a record included in our medicaldf data frame.

# %%
medicalgeocodes = pd.DataFrame.from_csv('/Users/stakats/Downloads/anommedicalgeocoded-edited.csv')

# %%
medicalgeocodes
# Out:
#                                          normalized        lat        lng
# 0                 Bourbon, Île (Mascareignes, Îles) -21.150000  55.500000
# 1                                     Surate (Inde)  21.195000  72.819400
# 2                                Landau (Allemagne)  51.344100   9.084000
# 3                               Chandernagor (Inde)  22.855900  88.380000
# 4                La Balise (Louisiane ; États-Unis)  29.126400 -89.088100
# 5              Artois, Région géographique (France)  50.500000   2.500000
# 6                Fort-Royal (Martinique, Île de la)  14.610800 -61.071800
# 7              Guérande (Loire-Atlantique ; France)  47.333300  -2.433300
# 8                             Boën (Loire ; France)  45.744500   4.005000
# 9              Saint-Pierre (Martinique, Île de la)  14.742500 -61.175000
# 10                       Étampes (Essonne ; France)  48.433000   2.175800
# 11                  Savannah (Géorgie ; États-Unis)  32.084900 -81.118900
# 12                            Lille (Nord ; France)  50.640100   3.055900
# 13      Toulon-sur-Arroux (Saône-et-Loire ; France)  46.692900   4.139100
# 14            Rivière-Salée (Martinique, Île de la)  14.531000 -60.980000
# 15                                          Espagne  40.463667  -3.749220
# 16                    Saint-Vincent, Île (Antilles)  13.260000 -61.179400
# 17               Les Cayes (Saint-Domingue, Île de)  18.200000 -73.750000
# 18                 La Mobile (Alabama ; États-Unis)  30.656024 -88.031109
# 19                             Amokou, Fort (Ghana)   5.202500   1.090270
# 20                       Brest (Finistère ; France)  48.387300  -4.487900
# 21      Môle-Saint-Nicolas (Saint-Domingue, Île de)  19.800000 -73.383300
# 22                          Gorée, Île de (Sénégal)  14.667860 -17.398928
# 23          Port-au-Prince (Saint-Domingue, Île de)  18.540000 -72.339900
# 24                 Guadeloupe, Île de la (Antilles)  16.250000 -61.583333
# 25                Rennes (Ille-et-Vilaine ; France)  48.110000  -1.678300
# 26             Petit-Goave (Saint-Domingue, Île de)  18.431400 -72.866900
# 27                     Morlaix (Finistère ; France)  48.577100  -3.825000
# 28        Bourbonnais, Région géographique (France)  46.535600   3.192800
# 29         Nuits-Saint-Georges (Côte-d’Or ; France)  47.138300   4.951100
# ..                                              ...        ...        ...
# 124                                Namur (Belgique)  50.466700   4.866700
# 125                        Saint-Jean, Île (Canada)  46.384800 -63.369100
# 126  Bengale, Région géographique (Bangladesh/Inde)  24.422300  88.419400
# 127  Les Cayes-Saint-Louis (Saint-Domingue, Île de)  18.200000 -73.750000
# 128                              Mangicoupan (Inde)  11.756000  79.763000
# 129            Port-Margot (Saint-Domingue, Île de)  19.750000 -72.433300
# 130       Charleston (Caroline du Sud ; États-Unis)  32.796500 -79.946100
# 131         Bayonne (Pyrénées-Atlantiques ; France)  43.489800  -1.475900
# 132          Port-à-Piment (Saint-Domingue, Île de)  18.250000 -74.100000
# 133          Gascogne, Région géographique (France)  43.977000  -0.176000
# 134                        Auxerre (Yonne ; France)  47.799600   3.570300
# 135           Cap-Français (Saint-Domingue, Île de)  19.759900 -72.200000
# 136        Bonne Espérance, Cap de (Afrique du Sud) -34.358056  18.471944
# 137             Saint-Marc (Saint-Domingue, Île de)  19.116600 -72.700000
# 138                 Cluny (Saône-et-Loire ; France)  46.431500   4.660700
# 139                  Montpellier (Hérault ; France)  43.612500   3.875100
# 140         Ré, Île de (Charente-Maritime ; France)  46.222600  -1.469400
# 141                 Le Cap (Saint-Domingue, Île de)  19.759900 -72.200000
# 142                        Lectoure (Gers ; France)  43.934600   0.621100
# 143                Martinique, Île de la (Antilles)  14.666667 -61.000000
# 144                                Indes orientales  14.525556 -75.818333
# 145          Dauphiné, Région géographique (France)  45.383333   5.733333
# 146                              Mazulipatam (Inde)  16.184400  81.134900
# 147           Illinois, Territoire des (États-Unis)  41.800000 -89.360000
# 148           Saint-Pierre-et-Miquelon, Archipel de  46.933300 -56.333300
# 149                   Saint-Sever (Landes ; France)  43.757300  -0.573600
# 150     Oléron, Île d' (Charente-Maritime ; France)  45.924400  -1.286800
# 151              Marmelade (Saint-Domingue, Île de)  19.505500 -72.347300
# 152                       Saint-Louis, Fort (Bénin)   6.366667   2.083333
# 153                Angers (Maine-et-Loire ; France)  47.472800  -0.553900
#
# [154 rows x 3 columns]

# %% [markdown]
# ## Get ready to visualize ##
# Now we're finally ready to see something. We'll begin by defining some very basic mapping functions.

# %%
from IPython.display import HTML
import folium
 
def inline_map(map):
    """
    Embeds the HTML source of the map directly into the IPython notebook.
    
    This method will not work if the map depends on any files (json data). Also this uses
    the HTML5 srcdoc attribute, which may not be supported in all browsers.
    """
    map._build_map()
    return HTML('<iframe srcdoc="{srcdoc}" style="width: 100%; height: 510px; border: none"></iframe>'.format(srcdoc=map.HTML.replace('"', '&quot;')))
 
def embed_map(map, path):
    """
    Embeds a linked iframe to the map into the IPython notebook.
    
    Note: this method will not capture the source of the map into the notebook.
    This method should work for all maps (as long as they use relative urls).
    """
    map.create_map(path=path)
    return HTML('<iframe src="files/{path}" style="width: 100%; height: 510px; border: none"></iframe>'.format(path=path))

# %% [markdown]
# First let's map the all the unique locations that could appear on the map.

# %%
# We could use any number of pretty map backgrounds, but this one is relatively anodyne
tileset = 'http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png'
attribution = 'Tiles courtesy of <a href="http://openstreetmap.se/">OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href="http://www.openstreetmap.org/copyright">OpenStreetMap</a>'

fmap=folium.Map(location=[0, 0], zoom_start=2, tiles=tileset, attr=attribution)
def plotmarker(row):
    fmap.simple_marker( [row['latitude'], row['longitude']] )
for row in medicalgeocodes.iterrows():
    latlon = [ row[1]['lat'], row[1]['lng'] ]
    fmap.simple_marker(latlon, popup = row[1]['normalized'])
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_4776c5b8957448b08405c787853ce247&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_4776c5b8957448b08405c787853ce247', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([-21.15,
# 							55.5],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;Bourbon, &#206;le (Mascareignes, &#206;les)&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([21.195,
# 							72.8194],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;Surate (Inde)&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([51.3441,
# 							9.084],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;Landau (Allemagne)&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([22.8559,
# 							88.38],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;Chandernagor (Inde)&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([29.1264,
# 							-89.0881],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;La Balise (Louisiane ; &#201;tats-Unis)&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([50.5,
# 							2.5],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;Artois, R&#233;gion g&#233;ographique (France)&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([14.6108,
# 							-61.0718],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;Fort-Royal (Martinique, &#206;le de la)&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([47.3333,
# 							-2.4333],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;Gu&#233;rande (Loire-Atlantique ; France)&quot;);
#       marker_8._popup.options.maxWidth = 300;
#       map.addLayer(marker_8)
#
#       var marker_9_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_9 = L.marker([45.7445,
# 							4.005],
# 							{'icon':marker_9_icon}
# 							);
#       marker_9.bindPopup(&quot;Bo&#235;n (Loire ; France)&quot;);
#       marker_9._popup.options.maxWidth = 300;
#       map.addLayer(marker_9)
#
#       var marker_10_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_10 = L.marker([14.7425,
# 							-61.175],
# 							{'icon':marker_10_icon}
# 							);
#       marker_10.bindPopup(&quot;Saint-Pierre (Martinique, &#206;le de la)&quot;);
#       marker_10._popup.options.maxWidth = 300;
#       map.addLayer(marker_10)
#
#       var marker_11_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_11 = L.marker([48.433,
# 							2.1758],

# %% [markdown]
# Now let's map the medical personnel themselves.

# %%
fmap=folium.Map(location=[0, 0], zoom_start=2, tiles=tileset, attr=attribution)
def plotmarker(row):
    fmap.simple_marker( [row['latitude'], row['longitude']] )
for row in medicaldf.iterrows():
    places = row[1]['placesnormalized']
    if isinstance(places, list):
        linepoints = []
        for place in places:
            result = medicalgeocodes.loc[medicalgeocodes['normalized'] == place]
            if not (result.empty):
                latlng = [ result['lat'].item(), result['lng'].item() ]
                linepoints.append(latlng)
                fmap.simple_marker(latlng, popup='<a href="http://anom.archivesnationales.culture.gouv.fr/'+
                                   row[1]['fullLink']+'">'+
                                   row[1]['fullRecord']+'</a>')
embed_map(fmap, 'all-med-people.html')
# Out:
# <iframe src="files/all-med-people.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# With so many points overlapping, this map is difficult to read. We can cluster the markers in order to gain a better sense of how they're distributed.

# %%
fmap=folium.Map(location=[0, 0], zoom_start=2, tiles=tileset, attr=attribution)
def plotmarker(row):
    fmap.simple_marker( [row['latitude'], row['longitude']] )
for row in medicaldf.iterrows():
    places = row[1]['placesnormalized']
    if isinstance(places, list):
        linepoints = []
        for place in places:
            result = medicalgeocodes.loc[medicalgeocodes['normalized'] == place]
            if not (result.empty):
                latlng = [ result['lat'].item(), result['lng'].item() ]
                linepoints.append(latlng)
                fmap.simple_marker(latlng, popup='<a href="http://anom.archivesnationales.culture.gouv.fr/'+
                                   row[1]['fullLink']+'">'+
                                   row[1]['fullRecord']+'</a>', clustered_marker=True)
embed_map(fmap, 'all-med-people-clustered.html')
# Out:
# <iframe src="files/all-med-people-clustered.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# What do we see? First, by geocoding locations, we immediately get a much clearer view of where colonial personnel physically were: while many records include obvious keywords, like Saint-Domingue, many others do not; instead they might only include the name of a river, at whose mouth a doctor was posted. Once we translate these records into latitude and longitude, we gain a much better sense of the spatial arrangement of medical personnel.
#
# These points cluster tightly around the key nodes of French colonial activity: the Caribbean (56%), North America (10%), Madagascar and the Mascarenes (9%), West Africa (7%), and India (5%). The remaining points, typically identifying the individual’s place of origin, fall in and around France (13%). The overwhelming importance of the Caribbean will come as little surprise, given the economic importance of sugar production and the intensive efforts to maintain healthy military and civilian and slave populations. Once we begin to examine them in slices (e.g. by decade), however, we find evidence of a significant shift in the geography of colonial medical practitioners, and in their mobility.
#
# We notice immediately that the total number of points significantly exceeds our initial total set of 526 "medical" personnnel. Plotting all 526 records 636 points on the map because some individuals have more than one location associated with them in the finding aid entry. Most notably there are 82 records "located" in France, usually because these records include the individual's place of origin, as well as a colonial location. We can identify these records pretty quickly just by drawing lines between the points of any records that contain more than one location.

# %%
fmap=folium.Map(location=[0, 0], zoom_start=2, tiles=tileset, attr=attribution)
def plotmarker(row):
    fmap.simple_marker( [row['latitude'], row['longitude']] )
for row in medicaldf.iterrows():
    places = row[1]['placesnormalized']
    if isinstance(places, list):
        linepoints = []
        for place in places:
            result = medicalgeocodes.loc[medicalgeocodes['normalized'] == place]
            if not (result.empty):
                latlng = [ result['lat'].item(), result['lng'].item() ]
                linepoints.append(latlng)
        if len(linepoints) > 1:
            fmap.line(locations=linepoints, line_weight=2, line_opacity=0.4)
embed_map(fmap, 'all-networks.html')
# Out:
# <iframe src="files/all-networks.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# Once we connect the dots, however, it becomes evident that many records link locations *among* the colonies, rather than simply between a colony and France. We see somethng that looks like a belt tying together the Caribbean, Madagascar, and India. This phenomenon is worth investigating further, so let's be sure to include line generation in our generic mapping function.
#
# It is important to note that these lines are not geographic trajectories, strictly speaking. They don’t tell us where or when someone started moving, or in what direction they traveled. They don’t tell us how long someone stayed in a given location or even what they did there. In fact, they don’t even tell us whether someone ever moved at all. Jacques-Antoine Ribet’s dossier, for example, lists Martinique and Île de Bourbon merely because Ribet was actively lobbying for a position in one of those two locations, not because he had actually served in them.

# %%
# Let's now make a copy of our medical data frame so that we can do some destructive operations on it.
medicaldf_sample_test = medicaldf

# %%
# remove  blank dates
medicaldf_sample_test = medicaldf_sample_test.loc[medicaldf_sample_test['enddate'] != '']

# %%
# convert dates to integers so we can compare them programmatically
# we'll get a warning here but ignore it
medicaldf_sample_test.startdate = medicaldf_sample_test.startdate.astype(int)
medicaldf_sample_test.enddate = medicaldf_sample_test.enddate.astype(int)
# Out:
# /usr/local/lib/python3.5/site-packages/pandas/core/generic.py:2177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# We've done some basic plotting of individuals on the map. Now let's see how things move over time. First we'll break our data sample up into slices by decade, with slightly longer periods at either end where things taper off.

# %%
medicaldf_sample_1690_1720 = medicaldf_sample_test[(1690 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1720)]
medicaldf_sample_1720_1730 = medicaldf_sample_test[(1720 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1730)]
medicaldf_sample_1730_1740 = medicaldf_sample_test[(1730 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1740)]
medicaldf_sample_1740_1750 = medicaldf_sample_test[(1740 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1750)]
medicaldf_sample_1750_1760 = medicaldf_sample_test[(1750 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1760)]
medicaldf_sample_1760_1770 = medicaldf_sample_test[(1760 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1770)]
medicaldf_sample_1770_1780 = medicaldf_sample_test[(1770 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1780)]
medicaldf_sample_1780_1800 = medicaldf_sample_test[(1780 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1800)]

# %% [markdown]
# Now let's build a generic mapping function that will let us map one of these samples, draw lines, and/or cluster the data points.

# %%
def map_anom(df, centered, zoom, lines, clustered):
    """
    Takes ANOM records, geocodes them according to normalized data
    variables are df, centered coordinates, zoom level, connecting lines, clustered points)
    """
    fmap=folium.Map(location=centered, zoom_start=zoom, tiles=tileset, attr=attribution)
    def plotmarker(row):
        fmap.simple_marker( [row['latitude'], row['longitude']] )
    for row in df.iterrows():
        places = row[1]['placesnormalized']
        if isinstance(places, list):
            linepoints = []
            for place in places:
                result = medicalgeocodes.loc[medicalgeocodes['normalized'] == place]
                if not (result.empty):
                    latlng = [ result['lat'].item(), result['lng'].item() ]
                    linepoints.append(latlng)
                    fmap.simple_marker(latlng, popup='<a href="http://anom.archivesnationales.culture.gouv.fr/'+
                                       row[1]['fullLink']+'">'+
                                       row[1]['fullRecord']+'</a>', clustered_marker=clustered)
            if lines & (len(linepoints) > 1):
                fmap.line(locations=linepoints, line_weight=2, line_opacity=0.4)
            
    return fmap

# %% [markdown]
# ## French Colonial Medical Practitioners, 1690-1720 ##

# %%
fmap = map_anom(medicaldf_sample_1690_1720, [0, 0], 2, True, True)
embed_map(fmap, '1690-1720.html')
# Out:
# <iframe src="files/1690-1720.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ## French Colonial Medical Practitioners, 1720-1730 ##

# %%
fmap = map_anom(medicaldf_sample_1720_1730, [0, 0], 2, True, True)
embed_map(fmap, '1720-1730.html')
# Out:
# <iframe src="files/1720-1730.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ## French Colonial Medical Practitioners, 1730-1740 ##

# %%
fmap = map_anom(medicaldf_sample_1730_1740, [0, 0], 2, True, True)
embed_map(fmap, '1730-1740.html')
# Out:
# <iframe src="files/1730-1740.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ## French Colonial Medical Practitioners, 1740-1750 ##

# %%
fmap = map_anom(medicaldf_sample_1740_1750, [0, 0], 2, True, True)
embed_map(fmap, '1740-1750.html')
# Out:
# <iframe src="files/1740-1750.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ## French Colonial Medical Practitioners, 1750-1760 ##

# %%
fmap = map_anom(medicaldf_sample_1750_1760, [0, 0], 2, True, True)
embed_map(fmap, '1750-1760.html')
# Out:
# <iframe src="files/1750-1760.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ## French Colonial Medical Practitioners, 1760-1770 ##

# %%
fmap = map_anom(medicaldf_sample_1760_1770, [0, 0], 2, True, True)
embed_map(fmap, '1760-1770.html')
# Out:
# <iframe src="files/1760-1770.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ## French Colonial Medical Practitioners, 1770-1780 ##

# %%
fmap = map_anom(medicaldf_sample_1770_1780, [0, 0], 2, True, True)
embed_map(fmap, '1770-1780.html')
# Out:
# <iframe src="files/1770-1780.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ## French Colonial Medical Practitioners, 1780-1800 ##

# %%
fmap = map_anom(medicaldf_sample_1780_1800, [0, 0], 2, True, True)
embed_map(fmap, '1780-1800.html')
# Out:
# <iframe src="files/1780-1800.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ### Discussion of mapping over time ###
# Once we begin to examine them in slices (e.g. by decade), however, we find evidence of a significant shift in the geography of colonial medical practitioners, and perhaps in their mobility.
#
# In absolute terms, the number of medical practitioners increases significantly decade by decade, with an important inflection point around 1770, with records of medical practitioners doubling nearly every decade through the end of the Old Regime.
#
# As the numbers grow the allocation by region shifts: by 1770 15% are in West Africa and the Indian Ocean, up from essentially zero, and by 1780 over a quarter are there, a presence maintained through the end of the Old Regime.

# %% [markdown]
# ## Investigating "French" Locations ##
# What can we learn by looking at the data points located in France? Like the multiple data points that produced lines, these "French" pieces of data initially seemed superfluous or even annoying. But let's take a closer see to how "France" appears when we look more closely. There aren't any "French" locations listed before 1720, so we'll begin with that slice of the data.

# %% [markdown]
# ### Origins, 1720-1730 ###

# %%
fmap = map_anom(medicaldf_sample_1720_1730, [45.7831, 3.0824], 6, False, False)
embed_map(fmap, 'origins-1720-1730.html')
# Out:
# <iframe src="files/origins-1720-1730.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ### Origins, 1730-1740 ###

# %%
fmap = map_anom(medicaldf_sample_1730_1740, [45.7831, 3.0824], 6, False, False)
embed_map(fmap, 'origins-1730-1740.html')
# Out:
# <iframe src="files/origins-1730-1740.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ### Origins, 1740-1750 ###

# %%
fmap = map_anom(medicaldf_sample_1740_1750, [45.7831, 3.0824], 6, False, False)
embed_map(fmap, 'origins-1740-1750.html')
# Out:
# <iframe src="files/origins-1740-1750.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ### Origins, 1750-1760 ###

# %%
fmap = map_anom(medicaldf_sample_1750_1760, [45.7831, 3.0824], 6, False, False)
embed_map(fmap, 'origins-1750-1760.html')
# Out:
# <iframe src="files/origins-1750-1760.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ### Origins, 1760-1770 ###

# %%
fmap = map_anom(medicaldf_sample_1760_1770, [45.7831, 3.0824], 6, False, False)
embed_map(fmap, 'origins-1760-1770.html')
# Out:
# <iframe src="files/origins-1760-1770.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ### Origins, 1770-1780 ###

# %%
fmap = map_anom(medicaldf_sample_1770_1780, [45.7831, 3.0824], 6, False, False)
embed_map(fmap, 'origins-1770-1780.html')
# Out:
# <iframe src="files/origins-1770-1780.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ### Origins, 1780-1800 ###

# %%
fmap = map_anom(medicaldf_sample_1780_1800, [45.7831, 3.0824], 6, False, False)
embed_map(fmap, 'origins-1780-1800.html')
# Out:
# <iframe src="files/origins-1780-1800.html" style="width: 100%; height: 510px; border: none"></iframe>

# %% [markdown]
# ## Origins Discussion ##
# Before 1750, most medical practitioners' origins are clustered in port cities or near centers of medical learning like Paris and Montpellier. From 1760 onward, we find increasing numbers of medical practitioners originating elsewhere in central and eastern France. This diversification of geographic origins demands further investigation.
