# %% [markdown]
# # Mapping Colonial Medical Expertise of the Old Regime #
# ### Sean Takats, George Mason University ###

# %% [markdown]
# In *la zone torride*, where French colonial efforts were effectively confined after the Seven Years War, profitable commerce and brutal mortality rates combined to produce a steady supply of desperate but paying patients. Just as the colonies of the Old Regime provided the chance for planters and traders to grow rich (faire fortune), they also promised to reward doctors who could keep those individuals healthy in the face of endemic disease. Chasing fame and wealth, hundreds of medical practitioners fanned out across the globe from France to support a growing colonial and military infrastructure. At the same time, they built up a new body of medical knowledge that might prove useful in the metropole, where neo-Hippocratic conceptions of disease and hygiene were pushed to their limits by colonial findings.
#
# Despite perceived importance of this endeavor, with a range of new royal institutions established to support it, few historical studies have treated colonial medical practitioners apart from their published medical treatises, and medical histories of the Old Regime largely neglect colonial medicine. This neglect reflects at least in part a methodological bias, which this paper addresses. While many of doctors recounted their colonial experiences in published articles and books, the vast majority did not, and records of their experiences remain largely ignored in the archives. Only by considering it in its totality can we regain a sense of the centrality of this exotic experience to contemporary medical practice.

# %% [markdown]
# ## *La Zone Torride* ##

# %% [markdown]
# ![title](img/dazille-tropics.jpg)

# %% [markdown]
# ## Archives nationales d'outre-mer, Série E ##
# ### Personnel colonial ancien ###

# %% [markdown]
# ![title](img/irel.png)

# %% [markdown]
# Each record in the finding aid looks something like this:
#
# *Artur, Jacques François, médecin et doyen du Conseil supérieur à Cayenne 1735/1781*

# %% [markdown]
# These entries are essentially just transcriptions of the brief descriptions that are handwritten onto each dossier’s folder.

# %% [markdown]
# ![title](img/artur.jpg)

# %% [markdown]
# We can immediately see that there’s a significant amount of information in this record that could be useful to us: name, occupation, location, and time. Each record in the finding aid contains at least a name, and most contain a full complement of data, often with multiple locations (more on this later).
#
# A finding aid like this one, however, is typically used to conduct a search. And search as a research strategy is, of course, problematic. The finding aid itself is not granted any particular significance or use in its own right. For example, if I wanted to find out something about doctors, I might search for “médecin” and find some records, including Artur’s. Or I might be interested in Guyane and search “Cayenne”, again finding his record. But both of those searches presuppose a great deal. I’ve already decided to look for “Cayenne” but how do I even know if Guyana is important at all? Things get even more complicated if I want to think about time. How can I find records of individuals that intersect with a certain period? To make such queries possible, we can instead consider the finding aid in the aggregate, to identify times and places that may encourage further investigation. In other words, why not attempt a distant reading of the records, via computational analysis of their metadata?

# %% [markdown]
# ## Data Processing ##
# I downloaded and processed all 19,338 entries in the finding aid for [Série E of the Archives nationales d’Outre-Mer](http://anom.archivesnationales.culture.gouv.fr/ark:/61561/up424ojc). This finding aid indexes 63 linear meters of records, stored in 441 cartons.
#
# Once I had loaded all the records into a database, I then extracted the metadata from each record: personal name, place name(s), and military corps name (persname, geogname, and corpname, in ANOM’s schema), along with any years provided. With the Series E records now searchable, sortable, and (most important) containing structured data, I could then begin to view the dataset in the aggregate. At this stage, however, we are still working with fundamentally qualitative data (other than the years).

# %%
import re, sys
import pandas as pd, numpy as np
import pickle
from bs4 import BeautifulSoup

# %%
# Load downloaded ANOM data from pickle
personneldf = pd.read_pickle("./personneldf.pkl")

# %% [markdown]
# ## Filter "medical" personnel ##
# My next step was to pass the database of colonial agents through a filter to identify medical personnel, flagging any record that included “santé”, “médic”, “médecin”, or “chirurg”, a process which yields 526 records. With these records in hand and a geocoded database of locations, we can now plot these colonial personnel in time and space.

# %%
medicaldf = personneldf[personneldf.fullRecord.str.contains('santé|médic|médecin|chirurg')]

# %% [markdown]
# Once we download these records and extract all their metadata, we can easily work with them as a spreadsheet. Let's take a quick look at what this filtered data set looks like by returning its first ten records.

# %%
medicaldf.head(10)
# Out:
#                                                archref  \
# 85   <a class="archref" href="/ark:/61561/up424g0z0...
# 89   <a class="archref" href="/ark:/61561/up424rlkp...
# 102  <a class="archref" href="/ark:/61561/up424xrry...
# 118  <a class="archref" href="/ark:/61561/up424uoqr...
# 190  <a class="archref" href="/ark:/61561/up424rmkq...
# 245  <a class="archref" href="/ark:/61561/up424pkoj...
# 264  <a class="archref" href="/ark:/61561/up424niog...
# 267  <a class="archref" href="/ark:/61561/up424toup...
# 301  <a class="archref" href="/ark:/61561/up424dzx3...
# 372  <a class="archref" href="/ark:/61561/up424rnss...
#
#                            name          placesdisplay  \
# 85                Akers, Arétas        [Saint-Vincent]
# 89                     Alavoine       [Trois-Rivières]
# 102             Albert, Nicolas                    NaN
# 118                     Aleaume         [Sainte-Lucie]
# 190  Amelin de Lacroix, Charles       [Saint-Domingue]
# 245         Angerville, Côme d'         [Cap-Français]
# 264           Annibal, François  [Indes, Chandernagor]
# 267        Ansermet, Jean Louis        [île de France]
# 301                 Archambault           [Madagascar]
# 372               Arnoux, André               [Québec]
#
#                                       placesnormalized  \
# 85                     [Saint-Vincent, Île (Antilles)]
# 89                           [Trois-Rivières (Canada)]
# 102                                                NaN
# 118                     [Sainte-Lucie, Île (Antilles)]
# 190  [Saint-Domingue, Colonie française (Saint-Domi...
# 245            [Cap-Français (Saint-Domingue, Île de)]
# 264              [Inde française, Chandernagor (Inde)]
# 267              [France, Île de (Mascareignes, Îles)]
# 301                               [Madagascar, Île de]
# 372                                  [Québec (Canada)]
#
#                                           corp startdate enddate  daterange  \
# 85                                                  1783    1783  1783-1783
# 89   Hôpital général (Trois-Rivières ; Canada)      1757    1761  1757-1761
# 102                                                 1786    1786  1786-1786
# 118                                                 1763    1763  1763-1763
# 190                                                 1770    1770  1770-1770
# 245                                                 1778    1780  1778-1780
# 264                                       None      1777    1778  1777-1778
# 267                                                 1774    1789  1774-1789
# 301                                                 1789    1789  1789-1789
# 372                                                 1746    1746  1746-1746
#
#        alldates                fullLink  \
# 85         1783  /ark:/61561/up424g0z0c
# 89   1757, 1761  /ark:/61561/up424rlkps
# 102        1786  /ark:/61561/up424xrryu
# 118        1763  /ark:/61561/up424uoqrg
# 190        1770  /ark:/61561/up424rmkqu
# 245  1778, 1780  /ark:/61561/up424pkojn
# 264  1777, 1778  /ark:/61561/up424niogg
# 267  1774, 1789  /ark:/61561/up424touph
# 301        1789  /ark:/61561/up424dzx3w
# 372        1746  /ark:/61561/up424rnssf
#
#                                             fullRecord
# 85   Akers, Arétas, habitant de l'île Saint-Vincent...
# 89   Alavoine, chirurgien-major à l'hôpital des Tro...
# 102  Albert, Nicolas, botaniste ayant le privilège ...
# 118   Aleaume, docteur en médecine à Sainte-Lucie 1763
# 190  Amelin de Lacroix, Charles, chirurgien, passé ...
# 245  Angerville, Côme d', chirurgien du Roi, au Cap...
# 264  Annibal, François, novice du vaisseau le Borde...
# 267  Ansermet, Jean Louis, chirurgien à l'île de Fr...
# 301  Archambault, proposé pour chirurgien-major à M...
# 372  Arnoux, André, chirurgien-major du Roi à Québe...

# %% [markdown]
# ## Geocode Place Names ##

# %% [markdown]
# My next step was to geocode the place names embedded in each record. I extracted all the place names from my database of colonial personnel, rendering a list of 1401 unique location names. Fortunately ANOM offers a geographic lookup service, [Assistant de recherche géographique](http://anom.archivesnationales.culture.gouv.fr/geo.php), which provides GPS coordinates for the vast majority of these locations. I wrote a small piece of code to look up each location in the Assistant de recherche and then add the returned coordinates to my list of unique locations. I entered the small number of unreturned locations by hand using Wikipedia's geocodes.
#
# For the purposes of this analysis, we'll only use those locations which are associated with at least one medical practitioner, i.e. ones that match a record included in our medicaldf data frame.

# %% [markdown]
# We'll load the the geocoded data from a saved CSV (where we did the hand-editing).

# %%
medicalgeocodes = pd.DataFrame.from_csv('/Users/stakats/Downloads/anommedicalgeocoded-edited.csv')

# %% [markdown]
# Let's examine the first ten records to see what the data looks like.

# %%
medicalgeocodes.head(10)
# Out:
#                              normalized      lat      lng
# 0     Bourbon, Île (Mascareignes, Îles) -21.1500  55.5000
# 1                         Surate (Inde)  21.1950  72.8194
# 2                    Landau (Allemagne)  51.3441   9.0840
# 3                   Chandernagor (Inde)  22.8559  88.3800
# 4    La Balise (Louisiane ; États-Unis)  29.1264 -89.0881
# 5  Artois, Région géographique (France)  50.5000   2.5000
# 6    Fort-Royal (Martinique, Île de la)  14.6108 -61.0718
# 7  Guérande (Loire-Atlantique ; France)  47.3333  -2.4333
# 8                 Boën (Loire ; France)  45.7445   4.0050
# 9  Saint-Pierre (Martinique, Île de la)  14.7425 -61.1750

# %% [markdown]
# ## Get ready to visualize ##

# %% [markdown]
# Now we're finally ready to see something. We'll begin by defining a very basic inline mapping function.

# %%
from IPython.display import HTML
import folium
 
def inline_map(map):
    """
    Embeds the HTML source of the map directly into the IPython notebook.
    
    This method will not work if the map depends on any files (json data). Also this uses
    the HTML5 srcdoc attribute, which may not be supported in all browsers.
    """
    map._build_map()
    return HTML('<iframe srcdoc="{srcdoc}" style="width: 100%; height: 510px; border: none"></iframe>'.format(srcdoc=map.HTML.replace('"', '&quot;')))

# %% [markdown]
# First let's map the all the unique locations that could appear on the map.

# %%
# We could use any number of pretty map backgrounds, but this one is relatively anodyne
tileset = 'http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png'
attribution = 'Tiles courtesy of <a href="http://openstreetmap.se/">OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href="http://www.openstreetmap.org/copyright">OpenStreetMap</a>'

fmap=folium.Map(location=[0, 0], zoom_start=2, tiles=tileset, attr=attribution)
def plotmarker(row):
    fmap.simple_marker( [row['latitude'], row['longitude']] )
for row in medicalgeocodes.iterrows():
    latlon = [ row[1]['lat'], row[1]['lng'] ]
    fmap.simple_marker(latlon, popup = row[1]['normalized'])
fmap.create_map('locations.html') # we'll also save a copy outside of jupyter for other operations

# %%
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_aff0d32fec9740db99272f891b0425c6&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_aff0d32fec9740db99272f891b0425c6', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([-21.15,
# 							55.5],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;Bourbon, &#206;le (Mascareignes, &#206;les)&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([21.195,
# 							72.8194],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;Surate (Inde)&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([51.3441,
# 							9.084],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;Landau (Allemagne)&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([22.8559,
# 							88.38],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;Chandernagor (Inde)&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([29.1264,
# 							-89.0881],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;La Balise (Louisiane ; &#201;tats-Unis)&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([50.5,
# 							2.5],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;Artois, R&#233;gion g&#233;ographique (France)&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([14.6108,
# 							-61.0718],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;Fort-Royal (Martinique, &#206;le de la)&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([47.3333,
# 							-2.4333],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;Gu&#233;rande (Loire-Atlantique ; France)&quot;);
#       marker_8._popup.options.maxWidth = 300;
#       map.addLayer(marker_8)
#
#       var marker_9_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_9 = L.marker([45.7445,
# 							4.005],
# 							{'icon':marker_9_icon}
# 							);
#       marker_9.bindPopup(&quot;Bo&#235;n (Loire ; France)&quot;);
#       marker_9._popup.options.maxWidth = 300;
#       map.addLayer(marker_9)
#
#       var marker_10_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_10 = L.marker([14.7425,
# 							-61.175],
# 							{'icon':marker_10_icon}
# 							);
#       marker_10.bindPopup(&quot;Saint-Pierre (Martinique, &#206;le de la)&quot;);
#       marker_10._popup.options.maxWidth = 300;
#       map.addLayer(marker_10)
#
#       var marker_11_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_11 = L.marker([48.433,
# 							2.1758],

# %% [markdown]
# Now let's map the medical personnel themselves.

# %%
fmap=folium.Map(location=[0, 0], zoom_start=2, tiles=tileset, attr=attribution)
def plotmarker(row):
    fmap.simple_marker( [row['latitude'], row['longitude']] )
for row in medicaldf.iterrows():
    places = row[1]['placesnormalized']
    if isinstance(places, list):
        linepoints = []
        for place in places:
            result = medicalgeocodes.loc[medicalgeocodes['normalized'] == place]
            if not (result.empty):
                latlng = [ result['lat'].item(), result['lng'].item() ]
                linepoints.append(latlng)
                fmap.simple_marker(latlng, popup='<a href="http://anom.archivesnationales.culture.gouv.fr/'+
                                   row[1]['fullLink']+'">'+
                                   row[1]['fullRecord']+'</a>')
fmap.create_map('all-med-people.html')

# %%
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_27404a0445f54722bf20513870809d18&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_27404a0445f54722bf20513870809d18', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([13.26,
# 							-61.1794],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424g0z0c\&quot;>Akers, Ar&#233;tas, habitant de l'&#238;le Saint-Vincent, et Robins, chirurgien fran&#231;ais 1783</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([46.3498,
# 							-72.5585],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rlkps\&quot;>Alavoine, chirurgien-major &#224; l'h&#244;pital des Trois-Rivi&#232;res 1757/1761</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([13.9287,
# 							-60.9247],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uoqrg\&quot;>Aleaume, docteur en m&#233;decine &#224; Sainte-Lucie 1763</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rmkqu\&quot;>Amelin de Lacroix, Charles, chirurgien, pass&#233; pour Saint-Domingue 1770</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([19.7599,
# 							-72.2],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424pkojn\&quot;>Angerville, C&#244;me d', chirurgien du Roi, au Cap-Fran&#231;ais, &#224; Saint-Domingue 1778/1780</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([21.0,
# 							78.0],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424niogg\&quot;>Annibal, Fran&#231;ois, novice du vaisseau le Bordelais, mort aux Indes, Mathurin Adrien, matelot de l'Elisabeth de Chandernagor, et Fran&#231;ois Michel Brin, chirurgien-major de la Marine, mort aux Indes 1777/1778</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([22.8559,
# 							88.38],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424niogg\&quot;>Annibal, Fran&#231;ois, novice du vaisseau le Bordelais, mort aux Indes, Mathurin Adrien, matelot de l'Elisabeth de Chandernagor, et Fran&#231;ois Michel Brin, chirurgien-major de la Marine, mort aux Indes 1777/1778</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',pr

# %% [markdown]
# With so many points overlapping, this map is difficult to read. We can cluster the markers in order to gain a better sense of how they're distributed.

# %%
fmap=folium.Map(location=[0, 0], zoom_start=2, tiles=tileset, attr=attribution)
def plotmarker(row):
    fmap.simple_marker( [row['latitude'], row['longitude']] )
for row in medicaldf.iterrows():
    places = row[1]['placesnormalized']
    if isinstance(places, list):
        linepoints = []
        for place in places:
            result = medicalgeocodes.loc[medicalgeocodes['normalized'] == place]
            if not (result.empty):
                latlng = [ result['lat'].item(), result['lng'].item() ]
                linepoints.append(latlng)
                fmap.simple_marker(latlng, popup='<a href="http://anom.archivesnationales.culture.gouv.fr/'+
                                   row[1]['fullLink']+'">'+
                                   row[1]['fullRecord']+'</a>', clustered_marker=True)
fmap.create_map('all-med-people-clustered.html')

# %%
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_a2e0cd4a7f55455bb87877ada65f002b&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_a2e0cd4a7f55455bb87877ada65f002b', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([13.26,
# 							-61.1794],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424g0z0c\&quot;>Akers, Ar&#233;tas, habitant de l'&#238;le Saint-Vincent, et Robins, chirurgien fran&#231;ais 1783</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([46.3498,
# 							-72.5585],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rlkps\&quot;>Alavoine, chirurgien-major &#224; l'h&#244;pital des Trois-Rivi&#232;res 1757/1761</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([13.9287,
# 							-60.9247],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uoqrg\&quot;>Aleaume, docteur en m&#233;decine &#224; Sainte-Lucie 1763</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rmkqu\&quot;>Amelin de Lacroix, Charles, chirurgien, pass&#233; pour Saint-Domingue 1770</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([19.7599,
# 							-72.2],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424pkojn\&quot;>Angerville, C&#244;me d', chirurgien du Roi, au Cap-Fran&#231;ais, &#224; Saint-Domingue 1778/1780</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([21.0,
# 							78.0],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424niogg\&quot;>Annibal, Fran&#231;ois, novice du vaisseau le Bordelais, mort aux Indes, Mathurin Adrien, matelot de l'Elisabeth de Chandernagor, et Fran&#231;ois Michel Brin, chirurgien-major de la Marine, mort aux Indes 1777/1778</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([22.8559,
# 							88.38],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424niogg\&quot;>Annibal, Fran&#231;ois, novice du vaisseau le Bordelais, mort aux Indes, Mathurin Adrien, matelot de l'Elisabeth de Chandernagor, et Fran&#231;ois Michel Brin, chirurgien-major de la Marine, mort aux Indes 1777/1778</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'gl

# %% [markdown]
# What do we see? First, by geocoding locations, we immediately get a much clearer view of where colonial personnel physically were: while many records include obvious keywords, like Saint-Domingue, many others do not; instead they might only include the name of a river, at whose mouth a doctor was posted. Once we translate these records into latitude and longitude, we gain a much better sense of the spatial arrangement of medical personnel.
#
# These points cluster tightly around the key nodes of French colonial activity: the Caribbean (56%), North America (10%), Madagascar and the Mascarenes (9%), West Africa (7%), and India (5%). The remaining points, typically identifying the individual’s place of origin, fall in and around France (13%). The overwhelming importance of the Caribbean will come as little surprise, given the economic importance of sugar production and the intensive efforts to maintain healthy military and civilian and slave populations. Once we begin to examine them in slices (e.g. by decade), however, we find evidence of a significant shift in the geography of colonial medical practitioners, and in their mobility.
#
# We notice immediately that the total number of points significantly exceeds our initial total set of 526 "medical" personnnel. Plotting all 526 records 636 points on the map because some individuals have more than one location associated with them in the finding aid entry. Most notably there are 82 records "located" in France, usually because these records include the individual's place of origin, as well as a colonial location. We can identify these records pretty quickly just by drawing lines between the points of any records that contain more than one location.

# %% [markdown]
# Once we connect the dots, however, it becomes evident that many records link locations *among* the colonies, rather than simply between a colony and France. We see somethng that looks like a belt tying together the Caribbean, Madagascar, and India. This phenomenon is worth investigating further, so let's be sure to include line generation in our generic mapping function.

# %%
fmap=folium.Map(location=[0, 0], zoom_start=2, tiles=tileset, attr=attribution)
def plotmarker(row):
    fmap.simple_marker( [row['latitude'], row['longitude']] )
for row in medicaldf.iterrows():
    places = row[1]['placesnormalized']
    if isinstance(places, list):
        linepoints = []
        for place in places:
            result = medicalgeocodes.loc[medicalgeocodes['normalized'] == place]
            if not (result.empty):
                latlng = [ result['lat'].item(), result['lng'].item() ]
                linepoints.append(latlng)
        if len(linepoints) > 1:
            fmap.line(locations=linepoints, line_weight=2, line_opacity=0.4)
fmap.create_map('all-networks.html')

# %%
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_eab99ef33ff0476b91460a9be292a5bc&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_eab99ef33ff0476b91460a9be292a5bc', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#
#
#
#
#       var latLngs = [ [21.0, 78.0],  [22.8559, 88.38], ];
# var line_1 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_1);
#
#       var latLngs = [ [46.9333, -56.3333],  [14.666667000000002, -61.0],  [11.2431, -60.6665], ];
# var line_2 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_2);
#
#       var latLngs = [ [4.9316, -52.3155],  [4.9316, -52.3155], ];
# var line_3 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_3);
#
#       var latLngs = [ [45.7445, 4.005],  [19.7599, -72.2], ];
# var line_4 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_4);
#
#       var latLngs = [ [46.4315, 4.6607],  [46.666667, 4.7],  [4.9316, -52.3155], ];
# var line_5 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_5);
#
#       var latLngs = [ [49.1597, 5.3895],  [4.9316, -52.3155], ];
# var line_6 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_6);
#
#       var latLngs = [ [53.0, -70.0],  [43.6043, 1.4437], ];
# var line_7 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_7);
#
#       var latLngs = [ [47.1383, 4.9511],  [14.666667000000002, -61.0], ];
# var line_8 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_8);
#
#       var latLngs = [ [49.25, 4.0333],  [18.54, -72.3399], ];
# var line_9 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_9);
#
#       var latLngs = [ [46.5356, 3.1928],  [-20.3137, 57.5464], ];
# var line_10 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_10);
#
#       var latLngs = [ [46.2102, -60.7159],  [45.9373, -0.9665], ];
# var line_11 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_11);
#
#       var latLngs = [ [43.977, -0.17600000000000002],  [18.7815, -72.2571], ];
# var line_12 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_12);
#
#       var latLngs = [ [48.5, 7.5],  [-34.358056, 18.471944],  [11.93, 79.83], ];
# var line_13 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_13);
#
#       var latLngs = [ [43.2, 0.13333299999999998],  [18.7815, -72.2571], ];
# var line_14 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_14);
#
#       var latLngs = [ [11.93, 79.83],  [-20.3137, 57.5464],  [-21.15, 55.5], ];
# var line_15 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_15);
#
#       var latLngs = [ [32.0849, -81.1189],  [32.7965, -79.9461], ];
# var line_16 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_16);
#
#       var latLngs = [ [43.6125, 3.8751],  [13.26, -61.1794], ];
# var line_17 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_17);
#
#       var latLngs = [ [14.666667000000002, -61.0],  [4.28479, -51.622], ];
# var line_18 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_18);
#
#       var latLngs = [ [14.6108, -61.0718],  [48.8534, 2.3488], ];
# var line_19 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_19);
#
#       var latLngs = [ [44.2127, 4.5318],  [16.25, -61.583332999999996],  [44.1625, 4.6203],  [43.666667, 3.166667],  [45.5248, 4.8735],  [45.383333, 5.733333], ];
# var line_20 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_20);
#
#       var latLngs = [ [44.61, 2.0331],  [19.75, -72.4333], ];
# var line_21 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_21);
#
#       var latLngs = [ [12.1199, -61.6882],  [49.1167, 6.1826], ];
# var line_22 = L.polyline(latLngs,{
#
# weight: 2,
# opacity: 0.4,
# });
#
#       map.addLayer(line_22);
#
#       var latLngs = [ [21.0, 78.0],  [11.93, 79.83], ];
# var line_23 = L.polyline(latLngs,{

# %% [markdown]
# It is important to note that these lines are not geographic trajectories, strictly speaking. They don’t tell us where or when someone started moving, or in what direction they traveled. They don’t tell us how long someone stayed in a given location or even what they did there. In fact, they don’t even tell us whether someone ever moved at all. Jacques-Antoine Ribet’s dossier, for example, lists Martinique and Île de Bourbon merely because Ribet was actively lobbying for a position in one of those two locations, not because he had actually served in them.

# %%
# Let's now make a copy of our medical data frame so that we can do some destructive operations on it.
medicaldf_sample_test = medicaldf

# %%
# remove  blank dates
medicaldf_sample_test = medicaldf_sample_test.loc[medicaldf_sample_test['enddate'] != '']

# %%
# convert dates to integers so we can compare them programmatically
# we'll get a warning here but ignore it
medicaldf_sample_test.startdate = medicaldf_sample_test.startdate.astype(int)
medicaldf_sample_test.enddate = medicaldf_sample_test.enddate.astype(int)
# Out:
# /usr/local/lib/python3.5/site-packages/pandas/core/generic.py:2177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# We've done some basic plotting of individuals on the map. Now let's see how things move over time. First we'll break our data sample up into slices by decade, with slightly longer periods at either end where things taper off.

# %%
medicaldf_sample_1690_1720 = medicaldf_sample_test[(1690 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1720)]
medicaldf_sample_1720_1730 = medicaldf_sample_test[(1720 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1730)]
medicaldf_sample_1730_1740 = medicaldf_sample_test[(1730 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1740)]
medicaldf_sample_1740_1750 = medicaldf_sample_test[(1740 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1750)]
medicaldf_sample_1750_1760 = medicaldf_sample_test[(1750 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1760)]
medicaldf_sample_1760_1770 = medicaldf_sample_test[(1760 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1770)]
medicaldf_sample_1770_1780 = medicaldf_sample_test[(1770 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1780)]
medicaldf_sample_1780_1800 = medicaldf_sample_test[(1780 <= medicaldf_sample_test["enddate"]) & (medicaldf_sample_test["startdate"] <= 1800)]

# %% [markdown]
# Now let's build a generic mapping function that will let us map one of these samples, draw lines, and/or cluster the data points.

# %%
def map_anom(df, centered, zoom, lines, clustered):
    """
    Takes ANOM records, geocodes them according to normalized data
    variables are df, centered coordinates, zoom level, connecting lines, clustered points)
    """
    fmap=folium.Map(location=centered, zoom_start=zoom, tiles=tileset, attr=attribution)
    def plotmarker(row):
        fmap.simple_marker( [row['latitude'], row['longitude']] )
    for row in df.iterrows():
        places = row[1]['placesnormalized']
        if isinstance(places, list):
            linepoints = []
            for place in places:
                result = medicalgeocodes.loc[medicalgeocodes['normalized'] == place]
                if not (result.empty):
                    latlng = [ result['lat'].item(), result['lng'].item() ]
                    linepoints.append(latlng)
                    fmap.simple_marker(latlng, popup='<a href="http://anom.archivesnationales.culture.gouv.fr/'+
                                       row[1]['fullLink']+'">'+
                                       row[1]['fullRecord']+'</a>', clustered_marker=clustered)
            if lines & (len(linepoints) > 1):
                fmap.line(locations=linepoints, line_weight=2, line_opacity=0.4,
                          popup='<a href="http://anom.archivesnationales.culture.gouv.fr/'+
                          row[1]['fullLink']+'">'+row[1]['fullRecord']+'</a>')
            
    return fmap

# %% [markdown]
# ## French Colonial Medical Practitioners, 1690-1720 ##

# %%
fmap = map_anom(medicaldf_sample_1690_1720, [0, 0], 2, True, True)
fmap.create_map('1690-1720.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_54aac348af394382a25cfe8a29edabb1&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_54aac348af394382a25cfe8a29edabb1', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424auwvup\&quot;>Berbudau, Jean Gabriel, chirurgien &#224; l'&#238;le Royale 1709/1780</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424yzt0vy\&quot;>Gaston, ma&#238;tre-chirurgien &#224; la Martinique 1708</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rlkqspm\&quot;>La Grange, Jean de, chirurgien-major &#224; l'&#238;le Royale 1713/1724</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([46.8156,
# 							-71.2254],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424hbbcaao\&quot;>Lajus, chirurgien &#224; Qu&#233;bec 1709</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([50.4667,
# 							4.8667],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424oinjkmr\&quot;>R&#233;my, Dieudonn&#233; Joseph, originaire de Namur, m&#233;decin &#224; la Guadeloupe 1709/1784</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([16.25,
# 							-61.583332999999996],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424oinjkmr\&quot;>R&#233;my, Dieudonn&#233; Joseph, originaire de Namur, m&#233;decin &#224; la Guadeloupe 1709/1784</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([30.656024100000003,
# 							-88.0311088],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424xrxwytb\&quot;>Servier, Jean, chirurgien-major &#224; la Mobile &#224; la Louisiane, testament 1720/1727</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([31.0,
# 							-92.0],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424xrxwytb\&quot;>Servi

# %% [markdown]
# ## French Colonial Medical Practitioners, 1720-1730 ##

# %%
fmap = map_anom(medicaldf_sample_1720_1730, [0, 0], 2, True, True)
fmap.create_map('1720-1730.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_a46b6621f35b43f3926f34546e82f764&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_a46b6621f35b43f3926f34546e82f764', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dxwxwz\&quot;>Bautier, chirurgien-major de la Martinique 1723</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([45.5003,
# 							-73.6464],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424jdekjt\&quot;>Benoist, chirurgien-major des troupes de Montr&#233;al m&#233;decin ad honores et Benoist, fils, aide-chirurgien 1730/1741</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424auwvup\&quot;>Berbudau, Jean Gabriel, chirurgien &#224; l'&#238;le Royale 1709/1780</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424tnqmnf\&quot;>Bernard de Maisonneuve, chirurgien-major &#224; Saint-Domingue 1729/1765</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uowpru\&quot;>Boneton, ancien chirurgien &#224; la Martinique, candidat &#224; une place de chirurgien-major &#224; Oyapock 1730</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([4.28479,
# 							-51.622],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uowpru\&quot;>Boneton, ancien chirurgien &#224; la Martinique, candidat &#224; une place de chirurgien-major &#224; Oyapock 1730</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([14.6108,
# 							-61.0718],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424ezxz3p\&quot;>Bordegaray, de, m&#233;decin du Roi, &#224; Fort-Royal &#224; la Martinique, sa place demand&#233;e par le sieur de Tran, m&#233;decin de la facult&#233; de Paris 1729</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([48.8534,
# 							2.3488],

# %% [markdown]
# ## French Colonial Medical Practitioners, 1730-1740 ##

# %%
fmap = map_anom(medicaldf_sample_1730_1740, [0, 0], 2, True, True)
fmap.create_map('1730-1740.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_ceed9b310b364af999dd5603629b2f61&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_ceed9b310b364af999dd5603629b2f61', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([4.9316,
# 							-52.3155],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424qnkos\&quot;>Artur, Jacques Fran&#231;ois, m&#233;decin et doyen du Conseil sup&#233;rieur &#224; Cayenne 1735/1781</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([45.5003,
# 							-73.6464],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424jdekjt\&quot;>Benoist, chirurgien-major des troupes de Montr&#233;al m&#233;decin ad honores et Benoist, fils, aide-chirurgien 1730/1741</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424auwvup\&quot;>Berbudau, Jean Gabriel, chirurgien &#224; l'&#238;le Royale 1709/1780</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424tnqmnf\&quot;>Bernard de Maisonneuve, chirurgien-major &#224; Saint-Domingue 1729/1765</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([46.8156,
# 							-71.2254],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424bvy02m\&quot;>Berthier, Michel, chirurgien-major &#224; Qu&#233;bec, et sa veuve 1733/1765</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uowpru\&quot;>Boneton, ancien chirurgien &#224; la Martinique, candidat &#224; une place de chirurgien-major &#224; Oyapock 1730</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([4.28479,
# 							-51.622],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uowpru\&quot;>Boneton, ancien chirurgien &#224; la Martinique, candidat &#224; une place de chirurgien-major &#224; Oyapock 1730</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([4.9316,
# 							-52.3155],
# 							{'icon':marker_8_icon}
# 							);
#       m

# %% [markdown]
# ## French Colonial Medical Practitioners, 1740-1750 ##

# %%
fmap = map_anom(medicaldf_sample_1740_1750, [0, 0], 2, True, True)
fmap.create_map('1740-1750.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_e4a3a33392be4bdeb9cc8134708b680e&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_e4a3a33392be4bdeb9cc8134708b680e', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([46.8156,
# 							-71.2254],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rnssf\&quot;>Arnoux, Andr&#233;, chirurgien-major du Roi &#224; Qu&#233;bec, sa veuve et ses six enfants Louis, Andr&#233;, Michel, Charles, Pierre, Marie Anne, Madeleine Arnoux 1746/an XII</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([4.9316,
# 							-52.3155],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424qnkos\&quot;>Artur, Jacques Fran&#231;ois, m&#233;decin et doyen du Conseil sup&#233;rieur &#224; Cayenne 1735/1781</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([31.0,
# 							-92.0],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424ystysj\&quot;>Benigne de Fontenette, m&#233;decin botaniste du Roi &#224; la Louisiane et conseiller au Conseil sup&#233;rieur de la colonie 1748/1763</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([45.5003,
# 							-73.6464],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424jdekjt\&quot;>Benoist, chirurgien-major des troupes de Montr&#233;al m&#233;decin ad honores et Benoist, fils, aide-chirurgien 1730/1741</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424auwvup\&quot;>Berbudau, Jean Gabriel, chirurgien &#224; l'&#238;le Royale 1709/1780</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424tnqmnf\&quot;>Bernard de Maisonneuve, chirurgien-major &#224; Saint-Domingue 1729/1765</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([46.8156,
# 							-71.2254],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424bvy02m\&quot;>Berthier, Michel, chirurgien-major &#224; Qu&#233;bec, et sa veuve 1733/1765</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([46.2

# %% [markdown]
# ## French Colonial Medical Practitioners, 1750-1760 ##

# %%
fmap = map_anom(medicaldf_sample_1750_1760, [0, 0], 2, True, True)
fmap.create_map('1750-1760.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_1c89866f6b9f4a188c6d2ee153868116&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_1c89866f6b9f4a188c6d2ee153868116', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([46.3498,
# 							-72.5585],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rlkps\&quot;>Alavoine, chirurgien-major &#224; l'h&#244;pital des Trois-Rivi&#232;res 1757/1761</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([4.9316,
# 							-52.3155],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424qnkos\&quot;>Artur, Jacques Fran&#231;ois, m&#233;decin et doyen du Conseil sup&#233;rieur &#224; Cayenne 1735/1781</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([46.3848,
# 							-63.3691],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424wxpqp\&quot;>Barbudeau, Gabriel, chirurgien des troupes d&#233;tach&#233;es &#224; l'&#238;le Saint-Jean, au Canada 1754/1771</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([31.0,
# 							-92.0],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424ystysj\&quot;>Benigne de Fontenette, m&#233;decin botaniste du Roi &#224; la Louisiane et conseiller au Conseil sup&#233;rieur de la colonie 1748/1763</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424auwvup\&quot;>Berbudau, Jean Gabriel, chirurgien &#224; l'&#238;le Royale 1709/1780</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424tnqmnf\&quot;>Bernard de Maisonneuve, chirurgien-major &#224; Saint-Domingue 1729/1765</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([46.8156,
# 							-71.2254],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424bvy02m\&quot;>Berthier, Michel, chirurgien-major &#224; Qu&#233;bec, et sa veuve 1733/1765</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;<a href=\&

# %% [markdown]
# ## French Colonial Medical Practitioners, 1760-1770 ##

# %%
fmap = map_anom(medicaldf_sample_1760_1770, [0, 0], 2, True, True)
fmap.create_map('1760-1770.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_3bfb5a9632964aaa8da1eef916f0484c&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_3bfb5a9632964aaa8da1eef916f0484c', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([46.3498,
# 							-72.5585],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rlkps\&quot;>Alavoine, chirurgien-major &#224; l'h&#244;pital des Trois-Rivi&#232;res 1757/1761</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([13.9287,
# 							-60.9247],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uoqrg\&quot;>Aleaume, docteur en m&#233;decine &#224; Sainte-Lucie 1763</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rmkqu\&quot;>Amelin de Lacroix, Charles, chirurgien, pass&#233; pour Saint-Domingue 1770</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([46.9333,
# 							-56.3333],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([11.2431,
# 							-60.6665],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([4.9316,
# 							-52.3155],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424qnkos\&quot;>Artur, Jacques Fran&#231;ois, m&#233;decin et doyen du Conseil sup&#233;rieur &#224; Cayenne 1735/1781</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([4.9316,
# 							-52.3155],
# 							{

# %% [markdown]
# ## French Colonial Medical Practitioners, 1770-1780 ##

# %%
fmap = map_anom(medicaldf_sample_1770_1780, [0, 0], 2, True, True)
fmap.create_map('1770-1780.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_bc5bff31e4bf494786af33817ae72cef&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_bc5bff31e4bf494786af33817ae72cef', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rmkqu\&quot;>Amelin de Lacroix, Charles, chirurgien, pass&#233; pour Saint-Domingue 1770</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([19.7599,
# 							-72.2],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424pkojn\&quot;>Angerville, C&#244;me d', chirurgien du Roi, au Cap-Fran&#231;ais, &#224; Saint-Domingue 1778/1780</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([21.0,
# 							78.0],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424niogg\&quot;>Annibal, Fran&#231;ois, novice du vaisseau le Bordelais, mort aux Indes, Mathurin Adrien, matelot de l'Elisabeth de Chandernagor, et Fran&#231;ois Michel Brin, chirurgien-major de la Marine, mort aux Indes 1777/1778</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([22.8559,
# 							88.38],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424niogg\&quot;>Annibal, Fran&#231;ois, novice du vaisseau le Bordelais, mort aux Indes, Mathurin Adrien, matelot de l'Elisabeth de Chandernagor, et Fran&#231;ois Michel Brin, chirurgien-major de la Marine, mort aux Indes 1777/1778</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([-20.3137,
# 							57.5464],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424touph\&quot;>Ansermet, Jean Louis, chirurgien &#224; l'&#238;le de France 1774/1789</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([46.9333,
# 							-56.3333],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)

# %% [markdown]
# ## French Colonial Medical Practitioners, 1780-1800 ##

# %%
fmap = map_anom(medicaldf_sample_1780_1800, [0, 0], 2, True, True)
fmap.create_map('1780-1800.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_79f09cac73b74fc69ffee4ae35193a95&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_79f09cac73b74fc69ffee4ae35193a95', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([13.26,
# 							-61.1794],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424g0z0c\&quot;>Akers, Ar&#233;tas, habitant de l'&#238;le Saint-Vincent, et Robins, chirurgien fran&#231;ais 1783</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([19.7599,
# 							-72.2],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424pkojn\&quot;>Angerville, C&#244;me d', chirurgien du Roi, au Cap-Fran&#231;ais, &#224; Saint-Domingue 1778/1780</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([-20.3137,
# 							57.5464],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424touph\&quot;>Ansermet, Jean Louis, chirurgien &#224; l'&#238;le de France 1774/1789</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([-20.0,
# 							47.0],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dzx3w\&quot;>Archambault, propos&#233; pour chirurgien-major &#224; Madagascar 1789</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([46.9333,
# 							-56.3333],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([11.2431,
# 							-60.6665],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([4.9316,
# 							-52.3155],

# %% [markdown]
# ### Discussion of mapping over time ###
# Once we begin to examine them in slices (e.g. by decade), however, we find evidence of a significant shift in the geography of colonial medical practitioners, and perhaps in their mobility.
#
# In absolute terms, the number of medical practitioners increases significantly decade by decade, with an important inflection point around 1770, with records of medical practitioners doubling nearly every decade through the end of the Old Regime.
#
# As the numbers grow the allocation by region shifts: by 1770 15% are in West Africa and the Indian Ocean, up from essentially zero, and by 1780 over a quarter are there, a presence maintained through the end of the Old Regime.

# %% [markdown]
# ## Investigating "French" Locations ##
# What can we learn by looking at the data points located in France? Like the multiple data points that produced lines, these "French" pieces of data initially seemed superfluous or even annoying. But let's take a closer see to how "France" appears when we look more closely. There aren't any "French" locations listed before 1720, so we'll begin with that slice of the data.

# %% [markdown]
# ### Origins, 1720-1730 ###

# %%
fmap = map_anom(medicaldf_sample_1720_1730, [45.7831, 3.0824], 5, False, False)
fmap.create_map('origins-1720-1730.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_fdd4732f120f43b9bdd68e8fd693fe8a&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_fdd4732f120f43b9bdd68e8fd693fe8a', {
#                                        center:[45.7831, 3.0824],
#                                        zoom: 5,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dxwxwz\&quot;>Bautier, chirurgien-major de la Martinique 1723</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([45.5003,
# 							-73.6464],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424jdekjt\&quot;>Benoist, chirurgien-major des troupes de Montr&#233;al m&#233;decin ad honores et Benoist, fils, aide-chirurgien 1730/1741</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424auwvup\&quot;>Berbudau, Jean Gabriel, chirurgien &#224; l'&#238;le Royale 1709/1780</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424tnqmnf\&quot;>Bernard de Maisonneuve, chirurgien-major &#224; Saint-Domingue 1729/1765</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uowpru\&quot;>Boneton, ancien chirurgien &#224; la Martinique, candidat &#224; une place de chirurgien-major &#224; Oyapock 1730</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([4.28479,
# 							-51.622],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uowpru\&quot;>Boneton, ancien chirurgien &#224; la Martinique, candidat &#224; une place de chirurgien-major &#224; Oyapock 1730</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([14.6108,
# 							-61.0718],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424ezxz3p\&quot;>Bordegaray, de, m&#233;decin du Roi, &#224; Fort-Royal &#224; la Martinique, sa place demand&#233;e par le sieur de Tran, m&#233;decin de la facult&#233; de Paris 1729</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([48.8534,

# %% [markdown]
# ### Origins, 1730-1740 ###

# %%
fmap = map_anom(medicaldf_sample_1730_1740, [45.7831, 3.0824], 5, False, False)
fmap.create_map('origins-1730-1740.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_ccb393cb62a7491b99c594061ce940d8&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_ccb393cb62a7491b99c594061ce940d8', {
#                                        center:[45.7831, 3.0824],
#                                        zoom: 5,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([4.9316,
# 							-52.3155],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424qnkos\&quot;>Artur, Jacques Fran&#231;ois, m&#233;decin et doyen du Conseil sup&#233;rieur &#224; Cayenne 1735/1781</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([45.5003,
# 							-73.6464],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424jdekjt\&quot;>Benoist, chirurgien-major des troupes de Montr&#233;al m&#233;decin ad honores et Benoist, fils, aide-chirurgien 1730/1741</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424auwvup\&quot;>Berbudau, Jean Gabriel, chirurgien &#224; l'&#238;le Royale 1709/1780</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424tnqmnf\&quot;>Bernard de Maisonneuve, chirurgien-major &#224; Saint-Domingue 1729/1765</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([46.8156,
# 							-71.2254],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424bvy02m\&quot;>Berthier, Michel, chirurgien-major &#224; Qu&#233;bec, et sa veuve 1733/1765</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uowpru\&quot;>Boneton, ancien chirurgien &#224; la Martinique, candidat &#224; une place de chirurgien-major &#224; Oyapock 1730</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([4.28479,
# 							-51.622],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uowpru\&quot;>Boneton, ancien chirurgien &#224; la Martinique, candidat &#224; une place de chirurgien-major &#224; Oyapock 1730</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([4.9316,
# 							-52.3155],
# 							{'icon':marker_8_ico

# %% [markdown]
# ### Origins, 1740-1750 ###

# %%
fmap = map_anom(medicaldf_sample_1740_1750, [45.7831, 3.0824], 5, False, False)
fmap.create_map('origins-1740-1750.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_61d5ec3542694fc8bdbfeb54e829ce36&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_61d5ec3542694fc8bdbfeb54e829ce36', {
#                                        center:[45.7831, 3.0824],
#                                        zoom: 5,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([46.8156,
# 							-71.2254],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rnssf\&quot;>Arnoux, Andr&#233;, chirurgien-major du Roi &#224; Qu&#233;bec, sa veuve et ses six enfants Louis, Andr&#233;, Michel, Charles, Pierre, Marie Anne, Madeleine Arnoux 1746/an XII</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([4.9316,
# 							-52.3155],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424qnkos\&quot;>Artur, Jacques Fran&#231;ois, m&#233;decin et doyen du Conseil sup&#233;rieur &#224; Cayenne 1735/1781</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([31.0,
# 							-92.0],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424ystysj\&quot;>Benigne de Fontenette, m&#233;decin botaniste du Roi &#224; la Louisiane et conseiller au Conseil sup&#233;rieur de la colonie 1748/1763</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([45.5003,
# 							-73.6464],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424jdekjt\&quot;>Benoist, chirurgien-major des troupes de Montr&#233;al m&#233;decin ad honores et Benoist, fils, aide-chirurgien 1730/1741</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424auwvup\&quot;>Berbudau, Jean Gabriel, chirurgien &#224; l'&#238;le Royale 1709/1780</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424tnqmnf\&quot;>Bernard de Maisonneuve, chirurgien-major &#224; Saint-Domingue 1729/1765</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([46.8156,
# 							-71.2254],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424bvy02m\&quot;>Berthier, Michel, chirurgien-major &#224; Qu&#233;bec, et sa veuve 1733/1765</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marke

# %% [markdown]
# ### Origins, 1750-1760 ###

# %%
fmap = map_anom(medicaldf_sample_1750_1760, [45.7831, 3.0824], 5, False, False)
fmap.create_map('origins-1750-1760.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_18e8b74a1926431c8847451d67f438a3&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_18e8b74a1926431c8847451d67f438a3', {
#                                        center:[45.7831, 3.0824],
#                                        zoom: 5,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([46.3498,
# 							-72.5585],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rlkps\&quot;>Alavoine, chirurgien-major &#224; l'h&#244;pital des Trois-Rivi&#232;res 1757/1761</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([4.9316,
# 							-52.3155],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424qnkos\&quot;>Artur, Jacques Fran&#231;ois, m&#233;decin et doyen du Conseil sup&#233;rieur &#224; Cayenne 1735/1781</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([46.3848,
# 							-63.3691],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424wxpqp\&quot;>Barbudeau, Gabriel, chirurgien des troupes d&#233;tach&#233;es &#224; l'&#238;le Saint-Jean, au Canada 1754/1771</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([31.0,
# 							-92.0],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424ystysj\&quot;>Benigne de Fontenette, m&#233;decin botaniste du Roi &#224; la Louisiane et conseiller au Conseil sup&#233;rieur de la colonie 1748/1763</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424auwvup\&quot;>Berbudau, Jean Gabriel, chirurgien &#224; l'&#238;le Royale 1709/1780</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424tnqmnf\&quot;>Bernard de Maisonneuve, chirurgien-major &#224; Saint-Domingue 1729/1765</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([46.8156,
# 							-71.2254],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424bvy02m\&quot;>Berthier, Michel, chirurgien-major &#224; Qu&#233;bec, et sa veuve 1733/1765</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([46.2102,
# 							-60.7159],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPo

# %% [markdown]
# ### Origins, 1760-1770 ###

# %%
fmap = map_anom(medicaldf_sample_1760_1770, [45.7831, 3.0824], 5, False, False)
fmap.create_map('origins-1760-1770.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_1a4c99d5daef4e4898eda6905f0d35df&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_1a4c99d5daef4e4898eda6905f0d35df', {
#                                        center:[45.7831, 3.0824],
#                                        zoom: 5,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([46.3498,
# 							-72.5585],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rlkps\&quot;>Alavoine, chirurgien-major &#224; l'h&#244;pital des Trois-Rivi&#232;res 1757/1761</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([13.9287,
# 							-60.9247],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uoqrg\&quot;>Aleaume, docteur en m&#233;decine &#224; Sainte-Lucie 1763</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rmkqu\&quot;>Amelin de Lacroix, Charles, chirurgien, pass&#233; pour Saint-Domingue 1770</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([46.9333,
# 							-56.3333],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([11.2431,
# 							-60.6665],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([4.9316,
# 							-52.3155],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424qnkos\&quot;>Artur, Jacques Fran&#231;ois, m&#233;decin et doyen du Conseil sup&#233;rieur &#224; Cayenne 1735/1781</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([4.9316,

# %% [markdown]
# ### Origins, 1770-1780 ###

# %%
fmap = map_anom(medicaldf_sample_1770_1780, [45.7831, 3.0824], 5, False, False)
fmap.create_map('origins-1770-1780.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_ee7571b4342d498095dba361adbda3a2&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_ee7571b4342d498095dba361adbda3a2', {
#                                        center:[45.7831, 3.0824],
#                                        zoom: 5,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rmkqu\&quot;>Amelin de Lacroix, Charles, chirurgien, pass&#233; pour Saint-Domingue 1770</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([19.7599,
# 							-72.2],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424pkojn\&quot;>Angerville, C&#244;me d', chirurgien du Roi, au Cap-Fran&#231;ais, &#224; Saint-Domingue 1778/1780</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([21.0,
# 							78.0],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424niogg\&quot;>Annibal, Fran&#231;ois, novice du vaisseau le Bordelais, mort aux Indes, Mathurin Adrien, matelot de l'Elisabeth de Chandernagor, et Fran&#231;ois Michel Brin, chirurgien-major de la Marine, mort aux Indes 1777/1778</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([22.8559,
# 							88.38],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424niogg\&quot;>Annibal, Fran&#231;ois, novice du vaisseau le Bordelais, mort aux Indes, Mathurin Adrien, matelot de l'Elisabeth de Chandernagor, et Fran&#231;ois Michel Brin, chirurgien-major de la Marine, mort aux Indes 1777/1778</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([-20.3137,
# 							57.5464],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424touph\&quot;>Ansermet, Jean Louis, chirurgien &#224; l'&#238;le de France 1774/1789</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([46.9333,
# 							-56.3333],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map

# %% [markdown]
# ### Origins, 1780-1800 ###

# %%
fmap = map_anom(medicaldf_sample_1780_1800, [45.7831, 3.0824], 5, False, False)
fmap.create_map('origins-1780-1800.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_505de0c1163c4b39b373636a9a5a3d70&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_505de0c1163c4b39b373636a9a5a3d70', {
#                                        center:[45.7831, 3.0824],
#                                        zoom: 5,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([13.26,
# 							-61.1794],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424g0z0c\&quot;>Akers, Ar&#233;tas, habitant de l'&#238;le Saint-Vincent, et Robins, chirurgien fran&#231;ais 1783</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([19.7599,
# 							-72.2],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424pkojn\&quot;>Angerville, C&#244;me d', chirurgien du Roi, au Cap-Fran&#231;ais, &#224; Saint-Domingue 1778/1780</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([-20.3137,
# 							57.5464],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424touph\&quot;>Ansermet, Jean Louis, chirurgien &#224; l'&#238;le de France 1774/1789</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([-20.0,
# 							47.0],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dzx3w\&quot;>Archambault, propos&#233; pour chirurgien-major &#224; Madagascar 1789</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([46.9333,
# 							-56.3333],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([11.2431,
# 							-60.6665],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([4.9316

# %% [markdown]
# ## Origins Discussion ##
# Before 1750, most medical practitioners' origins are clustered in port cities or near centers of medical learning like Paris and Montpellier. From 1760 onward, we find increasing numbers of medical practitioners originating elsewhere in central and eastern France. This diversification of geographic origins demands further investigation.

# %%
from geopy.distance import vincenty
def map_anom_exclude_france(df, centered, zoom, lines, clustered):
    """
    Takes ANOM records, geocodes them according to normalized data
    variables are df, centered coordinates, zoom level, connecting lines, clustered points)
    """
    fmap=folium.Map(location=centered, zoom_start=zoom, tiles=tileset, attr=attribution)
    def plotmarker(row):
        fmap.simple_marker( [row['latitude'], row['longitude']] )
    for row in df.iterrows():
        places = row[1]['placesnormalized']
        if isinstance(places, list):
            linepoints = []
            for place in places:
                result = medicalgeocodes.loc[medicalgeocodes['normalized'] == place]
                if not (result.empty):
                    latlng = [ result['lat'].item(), result['lng'].item() ]
                    # vincenty(newport_ri, cleveland_oh).miles
                    distance_from_france = vincenty(latlng, (45.7831, 3.0824)).miles
                    if distance_from_france > 800:
                        linepoints.append(latlng)
                    fmap.simple_marker(latlng, popup='<a href="http://anom.archivesnationales.culture.gouv.fr/'+
                                       row[1]['fullLink']+'">'+
                                       row[1]['fullRecord']+'</a>', clustered_marker=clustered)
            if lines & (len(linepoints) > 1):
                fmap.line(locations=linepoints, line_weight=2, line_opacity=0.4,
                          popup='<a href="http://anom.archivesnationales.culture.gouv.fr/'+
                          row[1]['fullLink']+'">'+row[1]['fullRecord']+'</a>')
            
    return fmap

# %%
fmap = map_anom_exclude_france(medicaldf_sample_1780_1800, [0, 0], 2, True, True)
fmap.create_map('exclude_france.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_658ac359e0dc42c29cf6606aa8204443&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_658ac359e0dc42c29cf6606aa8204443', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([13.26,
# 							-61.1794],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424g0z0c\&quot;>Akers, Ar&#233;tas, habitant de l'&#238;le Saint-Vincent, et Robins, chirurgien fran&#231;ais 1783</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([19.7599,
# 							-72.2],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424pkojn\&quot;>Angerville, C&#244;me d', chirurgien du Roi, au Cap-Fran&#231;ais, &#224; Saint-Domingue 1778/1780</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([-20.3137,
# 							57.5464],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424touph\&quot;>Ansermet, Jean Louis, chirurgien &#224; l'&#238;le de France 1774/1789</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([-20.0,
# 							47.0],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dzx3w\&quot;>Archambault, propos&#233; pour chirurgien-major &#224; Madagascar 1789</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([46.9333,
# 							-56.3333],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([14.666667000000002,
# 							-61.0],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([11.2431,
# 							-60.6665],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424dz5xy\&quot;>Arnoux, Joseph, chirurgien du roi &#224; Saint-Pierre et Miquelon, la Martinique et Tabago, fr&#232;re d'Andr&#233; Arnoux 1763/1783</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([4.9316,
# 							-52.3155],

# %% [markdown]
# ## Conclusions? ##

# %%
fmap = map_anom(medicaldf, [0, 0], 2, True, True)
fmap.create_map('all-locations-with-lines.html')
inline_map(fmap)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_24abbaba18e4460eb33d4410dfe8fad4&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.se/hydda/base/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Tiles courtesy of <a href=&quot;http://openstreetmap.se/&quot;>OpenStreetMap Sweden</a> &mdash; Map data &copy; <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_24abbaba18e4460eb33d4410dfe8fad4', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([13.26,
# 							-61.1794],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424g0z0c\&quot;>Akers, Ar&#233;tas, habitant de l'&#238;le Saint-Vincent, et Robins, chirurgien fran&#231;ais 1783</a>&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([46.3498,
# 							-72.5585],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rlkps\&quot;>Alavoine, chirurgien-major &#224; l'h&#244;pital des Trois-Rivi&#232;res 1757/1761</a>&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([13.9287,
# 							-60.9247],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424uoqrg\&quot;>Aleaume, docteur en m&#233;decine &#224; Sainte-Lucie 1763</a>&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([18.7815,
# 							-72.2571],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424rmkqu\&quot;>Amelin de Lacroix, Charles, chirurgien, pass&#233; pour Saint-Domingue 1770</a>&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([19.7599,
# 							-72.2],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424pkojn\&quot;>Angerville, C&#244;me d', chirurgien du Roi, au Cap-Fran&#231;ais, &#224; Saint-Domingue 1778/1780</a>&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([21.0,
# 							78.0],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424niogg\&quot;>Annibal, Fran&#231;ois, novice du vaisseau le Bordelais, mort aux Indes, Mathurin Adrien, matelot de l'Elisabeth de Chandernagor, et Fran&#231;ois Michel Brin, chirurgien-major de la Marine, mort aux Indes 1777/1778</a>&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([22.8559,
# 							88.38],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;<a href=\&quot;http://anom.archivesnationales.culture.gouv.fr//ark:/61561/up424niogg\&quot;>Annibal, Fran&#231;ois, novice du vaisseau le Bordelais, mort aux Indes, Mathurin Adrien, matelot de l'Elisabeth de Chandernagor, et Fran&#231;ois Michel Brin, chirurgien-major de la Marine, mort aux Indes 1777/1778</a>&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'gl

# %% [markdown]
# ## Try it yourself: github.com/stakats ##
# ![title](img/github.png)
